# %% [markdown]
# # Import

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import re
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedGroupKFold,StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, balanced_accuracy_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

FILE_PATH = Path('/Users/francesco/Tesi/BC-ML4/dataset/cleaned')


TIPO_FOLD = "kfold"
BALANCE_TEST = True
TARGET_MAP = {
    "duke": "HER2",
    "ambl": "HER2 [SII]",
    "duke_medsam": "HER2",
    "ambl_medsam": "HER2 [SII]"
}

# %% [markdown]
# # Funzioni

# %%
def load_dataset(file_path, csv_name):
    """Carica il CSV"""
    df = pd.read_csv(file_path)

    # Informazioni base sul dataset_name
    print(f"  Shape: {df.shape}")
    print(f"  Colonne: {df.shape[1]}")
    print(f"  Righe: {df.shape[0]}")
    # Mostro solo le prime 5 righe
    print(df.head(5))

    if "Patient ID" not in df.columns:
        raise ValueError(f"{csv_name} - manca 'Patient ID'")
    return df.copy()

def select_target(df, target_col):
    """Verifica che il target sia valido"""
    
    # Evito di addestrare su colonne sbagliate
    if target_col not in df.columns:
        raise ValueError(f"Colonna '{target_col}' mancante")
    
    # Mostro valori PRIMA della selezione
    print(f"\n VALORI TARGET PRIMA DELLA PULIZIA:")
    print(f"  Tipo: {df[target_col].dtype}")
    print(f"  Valori unici: {sorted(df[target_col].dropna().unique())}")
    print(f"  NaN: {df[target_col].isna().sum()}")
    print(f"\n  Distribuzione:")
    print(df[target_col].value_counts(dropna=False))
    y = df[target_col]
    
    if y.nunique() < 2:
        raise ValueError(f"Target '{target_col}' ha una sola classe")
    
    # Statistiche più dettagliate
    print(f"\n Target selezionato:")
    print(f"  Classe 0: {(y==0).sum()} ({(y==0).sum()/len(y)*100:.1f}%)")
    print(f"  Classe 1: {(y==1).sum()} ({(y==1).sum()/len(y)*100:.1f}%)")
    
    return df, y


def build_features_and_groups(df, target_col, dataset_type):
    print(f"\n{'='*80}")
    print(f"COSTRUZIONE FEATURES E GROUPS")
    print(f"{'='*80}")
    
    # Serve per la StratifiedGroupKFold
    groups = df["Patient ID"].copy()
    
    
    # Colonne comuni da rimuovere
    base_drop_cols = [
        "Patient ID", 
        "lesion idx", 
        "tumor/benign",
        "Breast",
        target_col
    ]

    # Definsico gli altri target da cancellare in base al csv
    if "duke" in dataset_type:
        other_targets = ["GRADE", "isTN", "ER", "PR"]
    elif "ambl" in dataset_type:  
        other_targets = ["ER [SII]", "PR [SII]"]
    else:
        raise ValueError(f"Dataset type '{dataset_type}' non riconosciuto")
    
    drop_cols = base_drop_cols + other_targets
    
    # Mostro quali colonne vengono rimosse
    print(f"\n COLONNE DA RIMUOVERE:")  
    print(f"  Base (metadati + target): {base_drop_cols}")
    print(f"  Altri target ({dataset_type}): {other_targets}")
    print(f"  Totale: {len(drop_cols)}")
    
    # Verifico l'esistenza delle colonne
    cols_found = [c for c in drop_cols if c in df.columns]
    cols_missing = [c for c in drop_cols if c not in df.columns]
    
    print(f"\n  Trovate: {len(cols_found)}")
    if cols_missing:
        print(f"  NON trovate (OK, verranno ignorate): {cols_missing}")
    
    # Rimuovo le colonne
    X = df.drop(columns=drop_cols, errors="ignore")

    print(f"\n Features estratte: {X.shape[1]} colonne, {X.shape[0]} righe")
    
    # Verifico tipi e Nan
    print(f"\n{'='*80}")
    print("VERIFICA DATI")
    print(f"{'='*80}")
    
    # Mostra tipi di dato
    print(f"\n TIPI DI DATO:")
    print(X.dtypes.value_counts())
    
    # Conta NaN
    nan_count = X.isna().sum().sum()
    print(f"\n NaN PRESENTI: {nan_count}")
    
    if nan_count > 0:
        print(f"\n  Colonne con NaN (top 10):")
        nan_cols = X.isna().sum()
        print(nan_cols[nan_cols > 0].sort_values(ascending=False).head(10))
        
        # Conta righe con NaN
        rows_with_nan = X.isna().any(axis=1).sum()
        print(f"\n Righe con almeno un NaN: {rows_with_nan}/{len(X)}")
        
        print(f"\n  Queste righe verranno rimosse nella pipeline principale")
    else:
        print(f"\n Nessun NaN presente")
    
    # Mostra prime righe
    print(f"\n PRIME 3 RIGHE DEL DATASET FINALE:")
    print(X.head(3).iloc[:, :5]) 
    
    print(f"\n{'='*80}")
    print("VERIFICA PULIZIA NOMI COLONNE")
    print(f"{'='*80}")

    cols_with_special = [c for c in X.columns if any(char in c for char in ['[', ']', '<'])]

    print(f"\nColonne con caratteri speciali: {len(cols_with_special)}")

    if len(cols_with_special) > 0:
        print(f"  Esempi: {cols_with_special[:5]}")
        X.columns = [re.sub(r"\[|\]|<", "", c) for c in X.columns]
        print(f" Nomi colonne puliti")
    else:
        print(f" Nessuna colonna con caratteri speciali")
        print(f" Pulizia NON necessaria per questo dataset")


    print(f"\n FEATURES FINALI: {X.shape}")
    
    return X, groups

# %% [markdown]
# # StratifiedGroupKFold, StratifiedKFold

# %%
def stratifiedgroup(X, y, n_splits, groups):
    sgkf = StratifiedGroupKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )
    return list(sgkf.split(X, y, groups))

# %%
def stratified(X, y, n_splits):
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )
    return list(skf.split(X, y))

# %% [markdown]
# # Bilanciameto

# %%
def balance_test_sets(cv_splits, y):
    """
    Bilancia i test set a 50/50.
    I campioni in eccesso vengono spostati al training set.
    """
    balanced_splits = []
    
    print(f"\n{'='*80}")
    print("BILANCIAMENTO DEI TEST SET")
    print(f"{'='*80}\n")
    
    for fold_num, (train_idx, test_idx) in enumerate(cv_splits, 1):
        y_test = y.iloc[test_idx]
        
        # Indici per classe
        mask_0 = (y_test == 0).values
        mask_1 = (y_test == 1).values
        
        idx_0 = test_idx[mask_0]
        idx_1 = test_idx[mask_1]
        
        n_0 = len(idx_0)
        n_1 = len(idx_1)
        n_min = min(n_0, n_1)
        
        print(f"Fold {fold_num}:")
        print(f"  PRIMA  - Test: Classe 0={n_0}, Classe 1={n_1}, Totale={len(test_idx)}")
        
        # Campiona n_min per classe (bilanciamento 50/50)
        np.random.seed(42 + fold_num)
        idx_0_sampled = np.random.choice(idx_0, size=n_min, replace=False)
        idx_1_sampled = np.random.choice(idx_1, size=n_min, replace=False)
        
        # Test bilanciato
        test_idx_balanced = np.concatenate([idx_0_sampled, idx_1_sampled])
        
        # Campioni non usati → training
        unused = np.setdiff1d(test_idx, test_idx_balanced)
        train_idx_new = np.concatenate([train_idx, unused])
        
        print(f"  DOPO   - Test: Classe 0={n_min}, Classe 1={n_min}, Totale={n_min*2}")
        print(f"           Train: {len(train_idx)} → {len(train_idx_new)} (+{len(unused)} campioni)\n")
        
        # Verifica che sia perfettamente bilanciato
        assert len(idx_0_sampled) == len(idx_1_sampled), "Test set non bilanciato!"
        
        balanced_splits.append((train_idx_new, test_idx_balanced))
    
    print(f" Split bilanciati creati con successo\n")
    return balanced_splits

# %% [markdown]
# # Get model

# %%
def get_model(params=None):
    model= RandomForestClassifier(
        random_state=42,
        n_jobs=1,
        class_weight="balanced_subsample"
    )
    if params is not None:
        model.set_params(**params)
    return model

# %% [markdown]
# # Grid Search

# %%
def gridsearch(X, y, splits):
    model = get_model()

    param_grid = {
        "n_estimators": [50, 75, 100],
        "max_depth": [2, 4, 6],
        "min_samples_leaf": [1, 2, 3]
    }


    grid = GridSearchCV(
        model,
        param_grid,
        cv=splits,
        scoring="f1",
        n_jobs=-1,
        verbose=1
    )

    grid.fit(X, y)
    return grid

# %% [markdown]
# # Valutazione fold

# %%
def evaluate_folds(X, y, splits, best_params):
    """
    Valuta il modello con i best params su ogni fold separatamente.
    Restituisce metriche per ogni fold.
    """
    fold_metrics = []
    
    for fold_num, (train_idx, test_idx) in enumerate(splits, 1):
        # Train
        model = get_model(best_params)

        model.set_params(**best_params)
        model.fit(X.iloc[train_idx], y.iloc[train_idx])
        
        # Test
        y_test = y.iloc[test_idx]
        y_pred = model.predict(X.iloc[test_idx])
        y_prob = model.predict_proba(X.iloc[test_idx])[:, 1]
        
        # Metriche
        f1 = f1_score(y.iloc[test_idx], y_pred, zero_division=0)
        acc = accuracy_score(y.iloc[test_idx], y_pred)
        bal_acc = balanced_accuracy_score(y.iloc[test_idx], y_pred)
        auc = roc_auc_score(y.iloc[test_idx], y_prob)
        
        # Se il test set è bilanciato, ACC dovrebbe = BAL_ACC
        diff = abs(acc - bal_acc)

        # Stampo le metrice dei test set
        if True:
            print(f"\n{'='*80}")
            print(f"FOLD {fold_num}/{len(splits)}")
            print(f"{'='*80}")
            print(f"\n{'─'*80}")
            print("METRICHE TEST SET")
            print(f"{'─'*80}")
            print(f"  F1-score:          {f1:.4f}")
            print(f"  Accuracy:          {acc:.4f}")
            print(f"  Balanced Accuracy: {bal_acc:.4f}")
            print(f"  Differenza:        {diff:.6f}", end="")
            
            # Stampo la matrice di confusione
            print(f"\n{'─'*80}")
            print("CONFUSION MATRIX")
            print(f"{'─'*80}")
            
            cm = confusion_matrix(y_test, y_pred)
            print(cm)
            
            tn, fp, fn, tp = cm.ravel()
            print(f"\n  TN={tn} | FP={fp} | FN={fn} | TP={tp}")
            
            if (tn + fp) > 0:
                recall_0 = tn / (tn + fp)
                print(f"  Classe 0: {tn}/{tn+fp} corretti ({recall_0*100:.1f}%)")
            
            if (fn + tp) > 0:
                recall_1 = tp / (fn + tp)
                print(f"  Classe 1: {tp}/{fn+tp} corretti ({recall_1*100:.1f}%)")

            # Stampo il classification report
            print(f"\n{'─'*80}")
            print("CLASSIFICATION REPORT")
            print(f"{'─'*80}")
            print(classification_report(y_test, y_pred, zero_division=0))
        fold_metrics.append({
            "fold": fold_num,
            "f1": f1,
            "acc": acc,
            "bal_acc": bal_acc,
            "auc": auc,
            "acc_bal_diff": diff
        })
    # Stampa riepilogo performance per fold
    print(f"\n{'='*80}")
    print("RIEPILOGO PERFORMANCE PER FOLD")
    print(f"{'='*80}")
    print(f"{'Fold':<8} {'F1-Score':<12} {'Accuracy':<12} {'Bal. Acc':<12} {'AUC':<12}")
    print(f"{'─'*80}")
    for m in fold_metrics:
        print(f"{m['fold']:<8} {m['f1']:<12.4f} {m['acc']:<12.4f} {m['bal_acc']:<12.4f} {m['auc']:<12.4f}")
    print(f"{'─'*80}")
    print(f"{'Mean':<8} {np.mean([m['f1'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['acc'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['bal_acc'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['auc'] for m in fold_metrics]):<12.4f}")
    print(f"{'Std':<8} {np.std([m['f1'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['acc'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['bal_acc'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['auc'] for m in fold_metrics]):<12.4f}")
    print(f"{'='*80}\n")
    return fold_metrics

# %% [markdown]
# # Training

# %%
def train(file_path, csv_name, dataset_type, tipo_fold, balance_test=False):
    """
    Pipeline completa di training per predizione PR.
    Esegue Grid Search con cross-validation e restituisce i migliori parametri.
    """
    print("\n" + "="*80)
    print(f"PROCESSING: {csv_name} ({dataset_type})")
    print("="*80)

    df = load_dataset(file_path, csv_name)

    target_col = TARGET_MAP[dataset_type]
    df, y = select_target(df, target_col)

    print(f"\nDistribuzione target:")
    for val in sorted(y.unique()):
        count = (y == val).sum()
        perc = count / len(y) * 100
        print(f"  Classe {val}: {count} ({perc:.1f}%)")

    # Preparo le feature e il group
    X, groups = build_features_and_groups(df, target_col, dataset_type)
    print(f"\n Features: {X.shape[1]} colonne")
    print(f" Campioni: {X.shape[0]}")
    print(f" Pazienti: {groups.nunique()}")


    # Creo gli split
    print(f"\n{'='*80}")
    print(f"CROSS-VALIDATION: {tipo_fold}")
    print(f"{'='*80}")

    if tipo_fold == "groupkfold":
        print(">>> StratifiedGroupKFold (pazienti separati)")
        splits_raw = stratifiedgroup(X, y, n_splits=5, groups=groups)
        
    elif tipo_fold == "kfold":
        print(">>> StratifiedKFold (standard)")
        splits_raw = stratified(X, y, n_splits=5)
        
    else:
        raise ValueError(
            f"tipo_fold '{tipo_fold}' non riconosciuto. "
            f"Usa: 'groupkfold' o 'kfold'"
        )
    
    # Bilancia test set se richiesto
    if balance_test:
        splits = balance_test_sets(splits_raw, y)
    else:
        splits = splits_raw
        print(f" Creati {len(splits)} fold (senza bilanciamento)")

    print(f" Creati {len(splits)} fold")

    # Eseguo la grid search
    grid = gridsearch(X, y, splits)

    fold_metrics = evaluate_folds(X, y, splits, grid.best_params_)

    # Calcola medie e std
    f1_scores = [m["f1"] for m in fold_metrics]
    acc_scores = [m["acc"] for m in fold_metrics]
    bal_acc_scores = [m["bal_acc"] for m in fold_metrics]
    auc_scores = [m["auc"] for m in fold_metrics]

    return {
        "dataset": csv_name,
        "target": target_col,
        "best_params": grid.best_params_,
        "mean_f1": np.mean(f1_scores),
        "std_f1": np.std(f1_scores),
        "mean_acc": np.mean(acc_scores),
        "std_acc": np.std(acc_scores),
        "mean_bal_acc": np.mean(bal_acc_scores),
        "std_bal_acc": np.std(bal_acc_scores),
        "mean_auc": np.mean(auc_scores),
        "std_auc": np.std(auc_scores),
        "fold_metrics": fold_metrics
    }

# %% [markdown]
# # Esecuzione

# %%
results = {}

results["DUKE_HER2"] = train(
    FILE_PATH / "duke_lesions.csv",
    "duke_lesions",
    dataset_type="duke",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["AMBL_HER2"] = train(
    FILE_PATH / "ambl_lesions_binary.csv",
    "ambl_lesions_binary",
    dataset_type="ambl",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["DUKE_medsam_HER2"] = train(
    FILE_PATH / "duke_lesions_radiomic_medsam.csv",
    "duke_lesions_radiomic_medsam",
    dataset_type="duke_medsam",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["AMBL_medsam_HER2"] = train(
    FILE_PATH / "ambl_lesions_radiomic_medsam_binary.csv",
    "ambl_lesions_radiomic_medsam_binary",
    dataset_type="ambl_medsam",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)
# Stampa risultati finali
print("\n" + "="*80)
print("RIEPILOGO FINALE")
print("="*80)

for name, res in results.items():
    print(f"\nDataset: {res['dataset']}")
    print("-" * 80)
    print(f" Target: {res['target']}")
    print(f"  F1-score         = {res['mean_f1']:.3f}  ±  {res['std_f1']:.3f}")
    print(f"  Accuracy         = {res['mean_acc']:.3f}  ±  {res['std_acc']:.3f}")
    print(f"  Balanced Acc     = {res['mean_bal_acc']:.3f}  ±  {res['std_bal_acc']:.3f}") 
    print(f"  AUC              = {res['mean_auc']:.3f}  ±  {res['std_auc']:.3f}")

rows = []

for name, res in results.items():
    row = {
        "experiment": name,
        "dataset": res["dataset"],
        "target": res["target"],
        "mean_f1": round(res["mean_f1"], 3),
        "std_f1": round(res["std_f1"], 3),
        "mean_accuracy": round(res["mean_acc"], 3),
        "std_accuracy": round(res["std_acc"], 3),
        "mean_balanced_accuracy": round(res["mean_bal_acc"], 3),
        "std_balanced_accuracy": round(res["std_bal_acc"], 3),
        "mean_auc": round(res["mean_auc"], 3),
        "std_auc": round(res["std_auc"], 3)
    }
    rows.append(row)

df_er = pd.DataFrame(rows)

output_path = "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/rf_singolo.csv"
file_exists = Path(output_path).exists()
df_er.to_csv(
    output_path,
    mode="a",                 # append
    header=not file_exists,   # header solo se file non esiste
    index=False
)

print(f"\nRisultati ER salvati in:\n{output_path}")
# Out:
# ================================================================================
# PROCESSING: duke_lesions (duke)
# ================================================================================
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.801733
# 1   DUKE_002   0   0     0                   0.595658
# 2   DUKE_005   1   0     1                   0.668824
# 3   DUKE_009   0   0     0                   0.680040
# 4   DUKE_010   0   0     0                   0.834884
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.727559                       17.331697
# 1                 0.262276                        6.491191
# 2                 0.462387                       18.682327
# 3                 0.543040                       16.896138
# 4                 0.566383                       22.952884
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       23.821699                               25.319289
# 1                       24.749465                               20.904455
# 2                       40.404115                               51.841254
# 3                       31.113997                               28.016591
# 4                       40.525347                               50.560680
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            27.939877  ...
# 1                            21.252044  ...
# 2                            49.529190  ...
# 3                            36.591695  ...
# 4                            49.711593  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       3.732730
# 1                                     816.019370
# 2                                      24.591161
# 3                                     507.049417
# 4                                    1695.066486
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.321169                    4.061870
# 1                                      0.002873                    6.566824
# 2                                      0.021288                    5.231952
# 3                                      0.001624                    6.788824
# 4                                      0.000581                    7.187445
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.019125                179288.204509
# 1                       0.476051                     8.279447
# 2                       0.037024                136797.383788
# 3                       0.307036                   191.988909
# 4                       0.505931                     7.282137
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                80.990253                   0.000911
# 1                 0.083176                   0.005217
# 2                24.588400                   0.000402
# 3                 0.408520                   0.000801
# 4                 0.736427                   0.000257
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   4.067385                 0.012786                 0.009999
# 1                3783.314508                 0.137734                 6.453010
# 2                  30.002001                 0.011011                 0.023444
# 3                6284.873277                 0.024907                 3.957295
# 4               11644.354499                 0.143078                 0.766544
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# HER2
# 0    208
# 1     83
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 208 (71.5%)
#   Classe 1: 83 (28.5%)
#
# Distribuzione target:
#   Classe 0: 208 (71.5%)
#   Classe 1: 83 (28.5%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'HER2']
#   Altri target (duke): ['GRADE', 'isTN', 'ER', 'PR']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.801733                 0.727559
# 1                   0.595658                 0.262276
# 2                   0.668824                 0.462387
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       17.331697                       23.821699
# 1                        6.491191                       24.749465
# 2                       18.682327                       40.404115
#
#    original_shape_Maximum2DDiameterColumn
# 0                               25.319289
# 1                               20.904455
# 2                               51.841254
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#
#  Features: 105 colonne
#  Campioni: 291
#  Pazienti: 291
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=42, Classe 1=17, Totale=59
#   DOPO   - Test: Classe 0=17, Classe 1=17, Totale=34
#            Train: 232 → 257 (+25 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=41, Classe 1=17, Totale=58
#   DOPO   - Test: Classe 0=17, Classe 1=17, Totale=34
#            Train: 233 → 257 (+24 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=41, Classe 1=17, Totale=58
#   DOPO   - Test: Classe 0=17, Classe 1=17, Totale=34
#            Train: 233 → 257 (+24 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=42, Classe 1=16, Totale=58
#   DOPO   - Test: Classe 0=16, Classe 1=16, Totale=32
#            Train: 233 → 259 (+26 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=42, Classe 1=16, Totale=58
#   DOPO   - Test: Classe 0=16, Classe 1=16, Totale=32
#            Train: 233 → 259 (+26 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5000
#   Accuracy:          0.5294
#   Balanced Accuracy: 0.5294
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[10  7]
#  [ 9  8]]
#
#   TN=10 | FP=7 | FN=9 | TP=8
#   Classe 0: 10/17 corretti (58.8%)
#   Classe 1: 8/17 corretti (47.1%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56        17
#            1       0.53      0.47      0.50        17
#
#     accuracy                           0.53        34
#    macro avg       0.53      0.53      0.53        34
# weighted avg       0.53      0.53      0.53        34
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.4516
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[10  7]
#  [10  7]]
#
#   TN=10 | FP=7 | FN=10 | TP=7
#   Classe 0: 10/17 corretti (58.8%)
#   Classe 1: 7/17 corretti (41.2%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      0.59      0.54        17
#            1       0.50      0.41      0.45        17
#
#     accuracy                           0.50        34
#    macro avg       0.50      0.50      0.50        34
# weighted avg       0.50      0.50      0.50        34
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5714
#   Accuracy:          0.5588
#   Balanced Accuracy: 0.5588
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 9  8]
#  [ 7 10]]
#
#   TN=9 | FP=8 | FN=7 | TP=10
#   Classe 0: 9/17 corretti (52.9%)
#   Classe 1: 10/17 corretti (58.8%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.56      0.53      0.55        17
#            1       0.56      0.59      0.57        17
#
#     accuracy                           0.56        34
#    macro avg       0.56      0.56      0.56        34
# weighted avg       0.56      0.56      0.56        34
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.2500
#   Accuracy:          0.4375
#   Balanced Accuracy: 0.4375
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11  5]
#  [13  3]]
#
#   TN=11 | FP=5 | FN=13 | TP=3
#   Classe 0: 11/16 corretti (68.8%)
#   Classe 1: 3/16 corretti (18.8%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.46      0.69      0.55        16
#            1       0.38      0.19      0.25        16
#
#     accuracy                           0.44        32
#    macro avg       0.42      0.44      0.40        32
# weighted avg       0.42      0.44      0.40        32
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6452
#   Accuracy:          0.6562
#   Balanced Accuracy: 0.6562
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11  5]
#  [ 6 10]]
#
#   TN=11 | FP=5 | FN=6 | TP=10
#   Classe 0: 11/16 corretti (68.8%)
#   Classe 1: 10/16 corretti (62.5%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67        16
#            1       0.67      0.62      0.65        16
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.66        32
# weighted avg       0.66      0.66      0.66        32
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.5000       0.5294       0.5294       0.4360
# 2        0.4516       0.5000       0.5000       0.3668
# 3        0.5714       0.5588       0.5588       0.4948
# 4        0.2500       0.4375       0.4375       0.4883
# 5        0.6452       0.6562       0.6562       0.6719
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.4836       0.5364       0.5364       0.4915
# Std      0.1339       0.0721       0.0721       0.1012
# ================================================================================
#
#
# ================================================================================
# PROCESSING: ambl_lesions_binary (ambl)
# ================================================================================
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.528082
# 1   AMBL-001         0         0           0                   0.336182
# 2   AMBL-003         0         0           0                   0.563923
# 3   AMBL-005         1         1           0                   0.761755
# 4   AMBL-007         1         0           0                   0.557584
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.375975                        8.551139
# 1                 0.293785                        7.651833
# 2                 0.394181                        8.781372
# 3                 0.641036                       20.245467
# 4                 0.366074                       18.597143
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.743875                               16.077739
# 1                       26.045677                               12.776208
# 2                       22.277510                               15.791279
# 3                       31.582394                               31.583382
# 4                       50.801628                               39.257160
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            26.863471  ...
# 1                            29.951350  ...
# 2                            22.006371  ...
# 3                            37.458189  ...
# 4                            60.793912  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      16.098904
# 1                                      10.777727
# 2                                       8.196991
# 3                                      28.274242
# 4                                       5.980941
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.043716                    4.536604
# 1                                      0.029528                    4.817406
# 2                                      0.075240                    5.007601
# 3                                      0.025064                    5.871338
# 4                                      0.067983                    4.739166
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.064252                  5792.756564
# 1                       0.093978                  1267.861250
# 2                       0.178138                   126.100723
# 3                       0.063874                  9578.078205
# 4                       0.031371                 91434.782971
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 2.775213                   0.005173
# 1                 2.353315                   0.007040
# 2                 2.067157                   0.011244
# 3                 6.402052                   0.001304
# 4                28.501489                   0.000872
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  19.975703                 0.014182                 0.183764
# 1                  25.004753                 0.040598                 0.210906
# 2                  24.083142                 0.051274                 0.292125
# 3                  91.217734                 0.049171                 0.116650
# 4                   9.737002                 0.018303                 0.016016
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# HER2 [SII]
# 0    68
# 1    14
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 68 (82.9%)
#   Classe 1: 14 (17.1%)
#
# Distribuzione target:
#   Classe 0: 68 (82.9%)
#   Classe 1: 14 (17.1%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'HER2 [SII]']
#   Altri target (ambl): ['ER [SII]', 'PR [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.528082                 0.375975
# 1                   0.336182                 0.293785
# 2                   0.563923                 0.394181
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.551139                       22.743875
# 1                        7.651833                       26.045677
# 2                        8.781372                       22.277510
#
#    original_shape_Maximum2DDiameterColumn
# 0                               16.077739
# 1                               12.776208
# 2                               15.791279
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#
#  Features: 105 colonne
#  Campioni: 82
#  Pazienti: 70
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=14, Classe 1=3, Totale=17
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 65 → 76 (+11 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=14, Classe 1=3, Totale=17
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 65 → 76 (+11 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=14, Classe 1=2, Totale=16
#   DOPO   - Test: Classe 0=2, Classe 1=2, Totale=4
#            Train: 66 → 78 (+12 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=13, Classe 1=3, Totale=16
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 66 → 76 (+10 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=13, Classe 1=3, Totale=16
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 66 → 76 (+10 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.0000
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [3 0]]
#
#   TN=3 | FP=0 | FN=3 | TP=0
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 0/3 corretti (0.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         6
#    macro avg       0.25      0.50      0.33         6
# weighted avg       0.25      0.50      0.33         6
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.0000
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [3 0]]
#
#   TN=3 | FP=0 | FN=3 | TP=0
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 0/3 corretti (0.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         6
#    macro avg       0.25      0.50      0.33         6
# weighted avg       0.25      0.50      0.33         6
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6667
#   Accuracy:          0.7500
#   Balanced Accuracy: 0.7500
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[2 0]
#  [1 1]]
#
#   TN=2 | FP=0 | FN=1 | TP=1
#   Classe 0: 2/2 corretti (100.0%)
#   Classe 1: 1/2 corretti (50.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.8000
#   Accuracy:          0.8333
#   Balanced Accuracy: 0.8333
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [1 2]]
#
#   TN=3 | FP=0 | FN=1 | TP=2
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 2/3 corretti (66.7%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.88      0.83      0.83         6
# weighted avg       0.88      0.83      0.83         6
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.0000
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [3 0]]
#
#   TN=3 | FP=0 | FN=3 | TP=0
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 0/3 corretti (0.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         6
#    macro avg       0.25      0.50      0.33         6
# weighted avg       0.25      0.50      0.33         6
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.0000       0.5000       0.5000       0.6667
# 2        0.0000       0.5000       0.5000       0.6667
# 3        0.6667       0.7500       0.7500       0.5000
# 4        0.8000       0.8333       0.8333       0.7778
# 5        0.0000       0.5000       0.5000       0.6667
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.2933       0.6167       0.6167       0.6556
# Std      0.3617       0.1453       0.1453       0.0889
# ================================================================================
#
#
# ================================================================================
# PROCESSING: duke_lesions_radiomic_medsam (duke_medsam)
# ================================================================================
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.956109
# 1   DUKE_002   0   0     0                   0.986617
# 2   DUKE_005   1   0     1                   0.531310
# 3   DUKE_009   0   0     0                   0.985995
# 4   DUKE_010   0   0     0                   0.913163
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.844657                       23.236690
# 1                 0.738184                       14.124854
# 2                 0.362991                       19.074218
# 3                 0.907380                       29.586478
# 4                 0.666651                       31.984526
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       27.510206                               33.841165
# 1                       19.134592                               21.804053
# 2                       52.547304                               55.177634
# 3                       32.606481                               40.022114
# 4                       47.977885                               60.524767
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            37.070079  ...
# 1                            25.679582  ...
# 2                            50.896657  ...
# 3                            42.657348  ...
# 4                            59.510315  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       4.065512
# 1                                     513.886736
# 2                                      20.795057
# 3                                     329.788184
# 4                                     938.945662
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.290643                    4.242751
# 1                                      0.013580                    7.206688
# 2                                      0.036582                    5.452188
# 3                                      0.004940                    7.262605
# 4                                      0.005418                    7.535492
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.017641                329513.249683
# 1                       0.507470                     9.310223
# 2                       0.039666                135505.922314
# 3                       0.301114                   212.257020
# 4                       0.569700                     4.200472
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0               116.318648                   0.000533
# 1                 0.471680                   0.002271
# 2                34.962085                   0.000325
# 3                 1.345384                   0.000424
# 4                 2.730941                   0.000165
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   7.410763                 0.012685                 0.010819
# 1                4216.436213                 0.432867                 3.156365
# 2                  30.408779                 0.017395                 0.016335
# 3                4459.712477                 0.074034                 1.055925
# 4               10483.944265                 0.453141                 0.369774
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# HER2
# 0    208
# 1     83
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 208 (71.5%)
#   Classe 1: 83 (28.5%)
#
# Distribuzione target:
#   Classe 0: 208 (71.5%)
#   Classe 1: 83 (28.5%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'HER2']
#   Altri target (duke_medsam): ['GRADE', 'isTN', 'ER', 'PR']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.956109                 0.844657
# 1                   0.986617                 0.738184
# 2                   0.531310                 0.362991
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       23.236690                       27.510206
# 1                       14.124854                       19.134592
# 2                       19.074218                       52.547304
#
#    original_shape_Maximum2DDiameterColumn
# 0                               33.841165
# 1                               21.804053
# 2                               55.177634
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#
#  Features: 105 colonne
#  Campioni: 291
#  Pazienti: 291
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=42, Classe 1=17, Totale=59
#   DOPO   - Test: Classe 0=17, Classe 1=17, Totale=34
#            Train: 232 → 257 (+25 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=41, Classe 1=17, Totale=58
#   DOPO   - Test: Classe 0=17, Classe 1=17, Totale=34
#            Train: 233 → 257 (+24 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=41, Classe 1=17, Totale=58
#   DOPO   - Test: Classe 0=17, Classe 1=17, Totale=34
#            Train: 233 → 257 (+24 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=42, Classe 1=16, Totale=58
#   DOPO   - Test: Classe 0=16, Classe 1=16, Totale=32
#            Train: 233 → 259 (+26 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=42, Classe 1=16, Totale=58
#   DOPO   - Test: Classe 0=16, Classe 1=16, Totale=32
#            Train: 233 → 259 (+26 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5294
#   Accuracy:          0.5294
#   Balanced Accuracy: 0.5294
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[9 8]
#  [8 9]]
#
#   TN=9 | FP=8 | FN=8 | TP=9
#   Classe 0: 9/17 corretti (52.9%)
#   Classe 1: 9/17 corretti (52.9%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.53      0.53      0.53        17
#            1       0.53      0.53      0.53        17
#
#     accuracy                           0.53        34
#    macro avg       0.53      0.53      0.53        34
# weighted avg       0.53      0.53      0.53        34
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.3636
#   Accuracy:          0.3824
#   Balanced Accuracy: 0.3824
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 7 10]
#  [11  6]]
#
#   TN=7 | FP=10 | FN=11 | TP=6
#   Classe 0: 7/17 corretti (41.2%)
#   Classe 1: 6/17 corretti (35.3%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.39      0.41      0.40        17
#            1       0.38      0.35      0.36        17
#
#     accuracy                           0.38        34
#    macro avg       0.38      0.38      0.38        34
# weighted avg       0.38      0.38      0.38        34
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5000
#   Accuracy:          0.5294
#   Balanced Accuracy: 0.5294
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[10  7]
#  [ 9  8]]
#
#   TN=10 | FP=7 | FN=9 | TP=8
#   Classe 0: 10/17 corretti (58.8%)
#   Classe 1: 8/17 corretti (47.1%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56        17
#            1       0.53      0.47      0.50        17
#
#     accuracy                           0.53        34
#    macro avg       0.53      0.53      0.53        34
# weighted avg       0.53      0.53      0.53        34
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.3846
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11  5]
#  [11  5]]
#
#   TN=11 | FP=5 | FN=11 | TP=5
#   Classe 0: 11/16 corretti (68.8%)
#   Classe 1: 5/16 corretti (31.2%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      0.69      0.58        16
#            1       0.50      0.31      0.38        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.48        32
# weighted avg       0.50      0.50      0.48        32
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5517
#   Accuracy:          0.5938
#   Balanced Accuracy: 0.5938
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11  5]
#  [ 8  8]]
#
#   TN=11 | FP=5 | FN=8 | TP=8
#   Classe 0: 11/16 corretti (68.8%)
#   Classe 1: 8/16 corretti (50.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        16
#            1       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.5294       0.5294       0.5294       0.4740
# 2        0.3636       0.3824       0.3824       0.3045
# 3        0.5000       0.5294       0.5294       0.5363
# 4        0.3846       0.5000       0.5000       0.4180
# 5        0.5517       0.5938       0.5938       0.5625
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.4659       0.5070       0.5070       0.4591
# Std      0.0770       0.0694       0.0694       0.0922
# ================================================================================
#
#
# ================================================================================
# PROCESSING: ambl_lesions_radiomic_medsam_binary (ambl_medsam)
# ================================================================================
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.632264
# 1   AMBL-001         0         0           0                   0.428066
# 2   AMBL-003         0         0           0                   0.853921
# 3   AMBL-005         1         1           0                   0.803782
# 4   AMBL-007         1         0           0                   0.631452
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.574573                       16.587860
# 1                 0.294263                       10.065943
# 2                 0.435016                        9.836007
# 3                 0.374899                       15.587523
# 4                 0.391559                       23.460339
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       28.869904                               22.120222
# 1                       34.207348                               17.412966
# 2                       22.610678                               21.247525
# 3                       41.577953                               34.491247
# 4                       59.915195                               44.173008
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            35.666937  ...
# 1                            36.743872  ...
# 2                            27.346457  ...
# 3                            42.427943  ...
# 4                            61.891243  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      11.866752
# 1                                       6.358452
# 2                                       8.132437
# 3                                      34.881141
# 4                                       5.821488
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.088645                    5.405028
# 1                                      0.055140                    5.483128
# 2                                      0.081316                    5.020232
# 3                                      0.025796                    5.568237
# 4                                      0.135345                    5.439009
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.043620                 17397.502279
# 1                       0.049725                  7036.435472
# 2                       0.054954                  4691.632692
# 3                       0.184971                   967.852818
# 4                       0.025776                106222.332082
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                13.115490                   0.001677
# 1                10.744731                   0.002468
# 2                 8.450972                   0.003567
# 3                 3.433053                   0.002188
# 4                57.721284                   0.000612
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  20.634441                 0.046452                 0.043755
# 1                  25.761844                 0.065802                 0.062361
# 2                  22.650386                 0.048524                 0.099512
# 3                 117.475529                 0.103989                 0.173719
# 4                  11.824437                 0.029061                 0.015007
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# HER2 [SII]
# 0    68
# 1    14
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 68 (82.9%)
#   Classe 1: 14 (17.1%)
#
# Distribuzione target:
#   Classe 0: 68 (82.9%)
#   Classe 1: 14 (17.1%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'HER2 [SII]']
#   Altri target (ambl_medsam): ['ER [SII]', 'PR [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.632264                 0.574573
# 1                   0.428066                 0.294263
# 2                   0.853921                 0.435016
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       16.587860                       28.869904
# 1                       10.065943                       34.207348
# 2                        9.836007                       22.610678
#
#    original_shape_Maximum2DDiameterColumn
# 0                               22.120222
# 1                               17.412966
# 2                               21.247525
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#
#  Features: 105 colonne
#  Campioni: 82
#  Pazienti: 70
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=14, Classe 1=3, Totale=17
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 65 → 76 (+11 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=14, Classe 1=3, Totale=17
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 65 → 76 (+11 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=14, Classe 1=2, Totale=16
#   DOPO   - Test: Classe 0=2, Classe 1=2, Totale=4
#            Train: 66 → 78 (+12 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=13, Classe 1=3, Totale=16
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 66 → 76 (+10 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=13, Classe 1=3, Totale=16
#   DOPO   - Test: Classe 0=3, Classe 1=3, Totale=6
#            Train: 66 → 76 (+10 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.0000
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [3 0]]
#
#   TN=3 | FP=0 | FN=3 | TP=0
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 0/3 corretti (0.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         6
#    macro avg       0.25      0.50      0.33         6
# weighted avg       0.25      0.50      0.33         6
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.0000
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [3 0]]
#
#   TN=3 | FP=0 | FN=3 | TP=0
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 0/3 corretti (0.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         6
#    macro avg       0.25      0.50      0.33         6
# weighted avg       0.25      0.50      0.33         6
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6667
#   Accuracy:          0.7500
#   Balanced Accuracy: 0.7500
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[2 0]
#  [1 1]]
#
#   TN=2 | FP=0 | FN=1 | TP=1
#   Classe 0: 2/2 corretti (100.0%)
#   Classe 1: 1/2 corretti (50.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.8000
#   Accuracy:          0.8333
#   Balanced Accuracy: 0.8333
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [1 2]]
#
#   TN=3 | FP=0 | FN=1 | TP=2
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 2/3 corretti (66.7%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.88      0.83      0.83         6
# weighted avg       0.88      0.83      0.83         6
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5000
#   Accuracy:          0.6667
#   Balanced Accuracy: 0.6667
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 0]
#  [2 1]]
#
#   TN=3 | FP=0 | FN=2 | TP=1
#   Classe 0: 3/3 corretti (100.0%)
#   Classe 1: 1/3 corretti (33.3%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         3
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.67         6
#    macro avg       0.80      0.67      0.62         6
# weighted avg       0.80      0.67      0.62         6
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.0000       0.5000       0.5000       0.8889
# 2        0.0000       0.5000       0.5000       0.3333
# 3        0.6667       0.7500       0.7500       0.5000
# 4        0.8000       0.8333       0.8333       0.7778
# 5        0.5000       0.6667       0.6667       0.3333
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.3933       0.6500       0.6500       0.5667
# Std      0.3349       0.1333       0.1333       0.2288
# ================================================================================
#
#
# ================================================================================
# RIEPILOGO FINALE
# ================================================================================
#
# Dataset: duke_lesions
# --------------------------------------------------------------------------------
#  Target: HER2
#   F1-score         = 0.484  ±  0.134
#   Accuracy         = 0.536  ±  0.072
#   Balanced Acc     = 0.536  ±  0.072
#   AUC              = 0.492  ±  0.101
#
# Dataset: ambl_lesions_binary
# --------------------------------------------------------------------------------
#  Target: HER2 [SII]
#   F1-score         = 0.293  ±  0.362
#   Accuracy         = 0.617  ±  0.145
#   Balanced Acc     = 0.617  ±  0.145
#   AUC              = 0.656  ±  0.089
#
# Dataset: duke_lesions_radiomic_medsam
# --------------------------------------------------------------------------------
#  Target: HER2
#   F1-score         = 0.466  ±  0.077
#   Accuracy         = 0.507  ±  0.069
#   Balanced Acc     = 0.507  ±  0.069
#   AUC              = 0.459  ±  0.092
#
# Dataset: ambl_lesions_radiomic_medsam_binary
# --------------------------------------------------------------------------------
#  Target: HER2 [SII]
#   F1-score         = 0.393  ±  0.335
#   Accuracy         = 0.650  ±  0.133
#   Balanced Acc     = 0.650  ±  0.133
#   AUC              = 0.567  ±  0.229
#
# Risultati ER salvati in:
# /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/rf_singolo.csv
