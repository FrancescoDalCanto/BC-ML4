# %% [markdown]
# # Import

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import re
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedGroupKFold,StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, balanced_accuracy_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

FILE_PATH = Path('/Users/francesco/Tesi/BC-ML4/dataset/cleaned')


TIPO_FOLD = "kfold"
BALANCE_TEST = True
TARGET_MAP = {
    "duke": "ER",
    "ambl": "ER [SII]",
    "duke_medsam": "ER",
    "ambl_medsam": "ER [SII]"
}

# %% [markdown]
# # Funzioni

# %%
def load_dataset(file_path, csv_name):
    """Carica il CSV"""
    df = pd.read_csv(file_path)

    # Informazioni base sul dataset_name
    print(f"  Shape: {df.shape}")
    print(f"  Colonne: {df.shape[1]}")
    print(f"  Righe: {df.shape[0]}")
    # Mostro solo le prime 5 righe
    print(df.head(5))

    if "Patient ID" not in df.columns:
        raise ValueError(f"{csv_name} - manca 'Patient ID'")
    return df.copy()

def select_target(df, target_col):
    """Verifica che il target sia valido"""
    
    # Evito di addestrare su colonne sbagliate
    if target_col not in df.columns:
        raise ValueError(f"Colonna '{target_col}' mancante")
    
    # Mostro valori PRIMA della selezione
    print(f"\n VALORI TARGET PRIMA DELLA PULIZIA:")
    print(f"  Tipo: {df[target_col].dtype}")
    print(f"  Valori unici: {sorted(df[target_col].dropna().unique())}")
    print(f"  NaN: {df[target_col].isna().sum()}")
    print(f"\n  Distribuzione:")
    print(df[target_col].value_counts(dropna=False))
    y = df[target_col]
    
    if y.nunique() < 2:
        raise ValueError(f"Target '{target_col}' ha una sola classe")
    
    # Statistiche più dettagliate
    print(f"\n Target selezionato:")
    print(f"  Classe 0: {(y==0).sum()} ({(y==0).sum()/len(y)*100:.1f}%)")
    print(f"  Classe 1: {(y==1).sum()} ({(y==1).sum()/len(y)*100:.1f}%)")
    
    return df, y


def build_features_and_groups(df, target_col, dataset_type):
    print(f"\n{'='*80}")
    print(f"COSTRUZIONE FEATURES E GROUPS")
    print(f"{'='*80}")
    
    # Serve per la StratifiedGroupKFold
    groups = df["Patient ID"].copy()
    
    
    # Colonne comuni da rimuovere
    base_drop_cols = [
        "Patient ID", 
        "lesion idx", 
        "tumor/benign",
        "Breast",
        target_col
    ]

    # Definsico gli altri target da cancellare in base al csv
    if "duke" in dataset_type:
        other_targets = ["GRADE", "isTN", "PR", "HER2"]
    elif "ambl" in dataset_type: 
        other_targets = ["PR [SII]", "HER2 [SII]"]
    else:
        raise ValueError(f"Dataset type '{dataset_type}' non riconosciuto")
    
    drop_cols = base_drop_cols + other_targets
    
    # Mostro quali colonne vengono rimosse
    print(f"\n COLONNE DA RIMUOVERE:")  
    print(f"  Base (metadati + target): {base_drop_cols}")
    print(f"  Altri target ({dataset_type}): {other_targets}")
    print(f"  Totale: {len(drop_cols)}")
    
    # Verifico l'esistenza delle colonne
    cols_found = [c for c in drop_cols if c in df.columns]
    cols_missing = [c for c in drop_cols if c not in df.columns]
    
    print(f"\n  Trovate: {len(cols_found)}")
    if cols_missing:
        print(f"  NON trovate (OK, verranno ignorate): {cols_missing}")
    
    # Rimuovo le colonne
    X = df.drop(columns=drop_cols, errors="ignore")

    print(f"\n Features estratte: {X.shape[1]} colonne, {X.shape[0]} righe")
    
    # Verifico tipi e Nan
    print(f"\n{'='*80}")
    print("VERIFICA DATI")
    print(f"{'='*80}")
    
    # Mostra tipi di dato
    print(f"\n TIPI DI DATO:")
    print(X.dtypes.value_counts())
    
    # Conta NaN
    nan_count = X.isna().sum().sum()
    print(f"\n NaN PRESENTI: {nan_count}")
    
    if nan_count > 0:
        print(f"\n  Colonne con NaN (top 10):")
        nan_cols = X.isna().sum()
        print(nan_cols[nan_cols > 0].sort_values(ascending=False).head(10))
        
        # Conta righe con NaN
        rows_with_nan = X.isna().any(axis=1).sum()
        print(f"\n Righe con almeno un NaN: {rows_with_nan}/{len(X)}")
        
        print(f"\n  Queste righe verranno rimosse nella pipeline principale")
    else:
        print(f"\n Nessun NaN presente")
    
    # Mostra prime righe
    print(f"\n PRIME 3 RIGHE DEL DATASET FINALE:")
    print(X.head(3).iloc[:, :5]) 
    
    print(f"\n{'='*80}")
    print("VERIFICA PULIZIA NOMI COLONNE")
    print(f"{'='*80}")

    cols_with_special = [c for c in X.columns if any(char in c for char in ['[', ']', '<'])]

    print(f"\nColonne con caratteri speciali: {len(cols_with_special)}")

    if len(cols_with_special) > 0:
        print(f"  Esempi: {cols_with_special[:5]}")
        X.columns = [re.sub(r"\[|\]|<", "", c) for c in X.columns]
        print(f" Nomi colonne puliti")
    else:
        print(f" Nessuna colonna con caratteri speciali")
        print(f" Pulizia NON necessaria per questo dataset")


    print(f"\n FEATURES FINALI: {X.shape}")
    
    return X, groups

# %% [markdown]
# # StratifiedGroupKFold, StratifiedKFold

# %%
def stratifiedgroup(X, y, n_splits, groups):
    sgkf = StratifiedGroupKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )
    return list(sgkf.split(X, y, groups))

# %%
def stratified(X, y, n_splits):
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )
    return list(skf.split(X, y))

# %% [markdown]
# # Bilanciameto

# %%
def balance_test_sets(cv_splits, y):
    """
    Bilancia i test set a 50/50.
    I campioni in eccesso vengono spostati al training set.
    """
    balanced_splits = []
    
    print(f"\n{'='*80}")
    print("BILANCIAMENTO DEI TEST SET")
    print(f"{'='*80}\n")
    
    for fold_num, (train_idx, test_idx) in enumerate(cv_splits, 1):
        y_test = y.iloc[test_idx]
        
        # Indici per classe
        mask_0 = (y_test == 0).values
        mask_1 = (y_test == 1).values
        
        idx_0 = test_idx[mask_0]
        idx_1 = test_idx[mask_1]
        
        n_0 = len(idx_0)
        n_1 = len(idx_1)
        n_min = min(n_0, n_1)
        
        print(f"Fold {fold_num}:")
        print(f"  PRIMA  - Test: Classe 0={n_0}, Classe 1={n_1}, Totale={len(test_idx)}")
        
        # Campiona n_min per classe (bilanciamento 50/50)
        np.random.seed(42 + fold_num)
        idx_0_sampled = np.random.choice(idx_0, size=n_min, replace=False)
        idx_1_sampled = np.random.choice(idx_1, size=n_min, replace=False)
        
        # Test bilanciato
        test_idx_balanced = np.concatenate([idx_0_sampled, idx_1_sampled])
        
        # Campioni non usati → training
        unused = np.setdiff1d(test_idx, test_idx_balanced)
        train_idx_new = np.concatenate([train_idx, unused])
        
        print(f"  DOPO   - Test: Classe 0={n_min}, Classe 1={n_min}, Totale={n_min*2}")
        print(f"           Train: {len(train_idx)} → {len(train_idx_new)} (+{len(unused)} campioni)\n")
        
        # Verifica che sia perfettamente bilanciato
        assert len(idx_0_sampled) == len(idx_1_sampled), "Test set non bilanciato!"
        
        balanced_splits.append((train_idx_new, test_idx_balanced))
    
    print(f" Split bilanciati creati con successo\n")
    return balanced_splits

# %% [markdown]
# # Get model

# %%
def get_model(params=None):
    model= RandomForestClassifier(
        random_state=42,
        n_jobs=1,
        class_weight="balanced_subsample"
    )
    if params is not None:
        model.set_params(**params)
    return model

# %% [markdown]
# # Feature Importance

# %%
def get_feature_importance(model, feature_names):
    """
    Estrae feature importance da modelli tree-based (XGBoost)
    o modelli lineari (Logistic Regression).
    Ritorna DataFrame ordinato.
    """

    # Caso Pipeline sklearn
    if hasattr(model, "named_steps"):
        final_model = list(model.named_steps.values())[-1]
    else:
        final_model = model

    # XGBoost, RandomForest, ecc.
    if hasattr(final_model, "feature_importances_"):
        importances = final_model.feature_importances_

    # Logistic Regression
    elif hasattr(final_model, "coef_"):
        importances = np.abs(final_model.coef_[0])

    else:
        raise ValueError("Modello non supportato per feature importance")

    df = pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })

    df = df.sort_values("importance", ascending=False)

    return df


def save_feature_importance(df_importance, output_path, top_n=15):
    df_importance.head(top_n).to_csv(output_path, index=False)
    print(f" Salvate top-{top_n} feature in: {output_path}")

# %% [markdown]
# # Grid Search

# %%
def gridsearch(X, y, splits):
    model = get_model()

    param_grid = {
        "n_estimators": [50, 75, 100],
        "max_depth": [2, 4, 6],
        "min_samples_leaf": [1, 2, 3]
    }


    grid = GridSearchCV(
        model,
        param_grid,
        cv=splits,
        scoring="f1",
        n_jobs=-1,
        verbose=1
    )

    grid.fit(X, y)
    return grid

# %% [markdown]
# # Valutazione fold

# %%
def evaluate_folds(X, y, splits, best_params):
    """
    Valuta il modello con i best params su ogni fold separatamente.
    Restituisce metriche per ogni fold.
    """
    fold_metrics = []
    
    for fold_num, (train_idx, test_idx) in enumerate(splits, 1):
        # Train
        model = get_model(best_params)

        model.set_params(**best_params)
        model.fit(X.iloc[train_idx], y.iloc[train_idx])
        
        # Test
        y_test = y.iloc[test_idx]
        y_pred = model.predict(X.iloc[test_idx])
        y_prob = model.predict_proba(X.iloc[test_idx])[:, 1]
        
        # Metriche
        f1 = f1_score(y.iloc[test_idx], y_pred, zero_division=0)
        acc = accuracy_score(y.iloc[test_idx], y_pred)
        bal_acc = balanced_accuracy_score(y.iloc[test_idx], y_pred)
        auc = roc_auc_score(y.iloc[test_idx], y_prob)
        
        # Se il test set è bilanciato, ACC dovrebbe = BAL_ACC
        diff = abs(acc - bal_acc)

        # Stampo le metrice dei test set
        if True:
            print(f"\n{'='*80}")
            print(f"FOLD {fold_num}/{len(splits)}")
            print(f"{'='*80}")
            print(f"\n{'─'*80}")
            print("METRICHE TEST SET")
            print(f"{'─'*80}")
            print(f"  F1-score:          {f1:.4f}")
            print(f"  Accuracy:          {acc:.4f}")
            print(f"  Balanced Accuracy: {bal_acc:.4f}")
            print(f"  Differenza:        {diff:.6f}", end="")
            
            # Stampo la matrice di confusione
            print(f"\n{'─'*80}")
            print("CONFUSION MATRIX")
            print(f"{'─'*80}")
            
            cm = confusion_matrix(y_test, y_pred)
            print(cm)
            
            tn, fp, fn, tp = cm.ravel()
            print(f"\n  TN={tn} | FP={fp} | FN={fn} | TP={tp}")
            
            if (tn + fp) > 0:
                recall_0 = tn / (tn + fp)
                print(f"  Classe 0: {tn}/{tn+fp} corretti ({recall_0*100:.1f}%)")
            
            if (fn + tp) > 0:
                recall_1 = tp / (fn + tp)
                print(f"  Classe 1: {tp}/{fn+tp} corretti ({recall_1*100:.1f}%)")

            # Stampo il classification report
            print(f"\n{'─'*80}")
            print("CLASSIFICATION REPORT")
            print(f"{'─'*80}")
            print(classification_report(y_test, y_pred, zero_division=0))
        fold_metrics.append({
            "fold": fold_num,
            "f1": f1,
            "acc": acc,
            "bal_acc": bal_acc,
            "auc": auc,
            "acc_bal_diff": diff
        })
    # Stampa riepilogo performance per fold
    print(f"\n{'='*80}")
    print("RIEPILOGO PERFORMANCE PER FOLD")
    print(f"{'='*80}")
    print(f"{'Fold':<8} {'F1-Score':<12} {'Accuracy':<12} {'Bal. Acc':<12} {'AUC':<12}")
    print(f"{'─'*80}")
    for m in fold_metrics:
        print(f"{m['fold']:<8} {m['f1']:<12.4f} {m['acc']:<12.4f} {m['bal_acc']:<12.4f} {m['auc']:<12.4f}")
    print(f"{'─'*80}")
    print(f"{'Mean':<8} {np.mean([m['f1'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['acc'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['bal_acc'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['auc'] for m in fold_metrics]):<12.4f}")
    print(f"{'Std':<8} {np.std([m['f1'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['acc'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['bal_acc'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['auc'] for m in fold_metrics]):<12.4f}")
    print(f"{'='*80}\n")
    return fold_metrics

# %% [markdown]
# # Training

# %%
def train(file_path, csv_name, dataset_type, tipo_fold, balance_test=False):
    """
    Pipeline completa di training per predizione PR.
    Esegue Grid Search con cross-validation e restituisce i migliori parametri.
    """
    print("\n" + "="*80)
    print(f"PROCESSING: {csv_name} ({dataset_type})")
    print("="*80)

    df = load_dataset(file_path, csv_name)

    target_col = TARGET_MAP[dataset_type]
    df, y = select_target(df, target_col)

    print(f"\nDistribuzione target:")
    for val in sorted(y.unique()):
        count = (y == val).sum()
        perc = count / len(y) * 100
        print(f"  Classe {val}: {count} ({perc:.1f}%)")

    # Preparo le feature e il group
    X, groups = build_features_and_groups(df, target_col, dataset_type)
    print(f"\n Features: {X.shape[1]} colonne")
    print(f" Campioni: {X.shape[0]}")
    print(f" Pazienti: {groups.nunique()}")


    # Creo gli split
    print(f"\n{'='*80}")
    print(f"CROSS-VALIDATION: {tipo_fold}")
    print(f"{'='*80}")

    if tipo_fold == "groupkfold":
        print(">>> StratifiedGroupKFold (pazienti separati)")
        splits_raw = stratifiedgroup(X, y, n_splits=5, groups=groups)
        
    elif tipo_fold == "kfold":
        print(">>> StratifiedKFold (standard)")
        splits_raw = stratified(X, y, n_splits=5)
        
    else:
        raise ValueError(
            f"tipo_fold '{tipo_fold}' non riconosciuto. "
            f"Usa: 'groupkfold' o 'kfold'"
        )
    
    # Bilancia test set se richiesto
    if balance_test:
        splits = balance_test_sets(splits_raw, y)
    else:
        splits = splits_raw
        print(f" Creati {len(splits)} fold (senza bilanciamento)")

    print(f" Creati {len(splits)} fold")

    # Eseguo la grid search
    grid = gridsearch(X, y, splits)

    fold_metrics = evaluate_folds(X, y, splits, grid.best_params_)

    # Calcola medie e std
    f1_scores = [m["f1"] for m in fold_metrics]
    acc_scores = [m["acc"] for m in fold_metrics]
    bal_acc_scores = [m["bal_acc"] for m in fold_metrics]
    auc_scores = [m["auc"] for m in fold_metrics]

    return {
        "dataset": csv_name,
        "target": target_col,
        "best_params": grid.best_params_,
        "mean_f1": np.mean(f1_scores),
        "std_f1": np.std(f1_scores),
        "mean_acc": np.mean(acc_scores),
        "std_acc": np.std(acc_scores),
        "mean_bal_acc": np.mean(bal_acc_scores),
        "std_bal_acc": np.std(bal_acc_scores),
        "mean_auc": np.mean(auc_scores),
        "std_auc": np.std(auc_scores),
        "fold_metrics": fold_metrics
    }

# %% [markdown]
# # Esecuzione

# %%
results = {}

results["DUKE_ER"] = train(
    FILE_PATH / "duke_lesions.csv",
    "duke_lesions",
    dataset_type="duke",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["AMBL_ER"] = train(
    FILE_PATH / "ambl_lesions_binary.csv",
    "ambl_lesions_binary",
    dataset_type="ambl",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["DUKE_medsam_ER"] = train(
    FILE_PATH / "duke_lesions_radiomic_medsam.csv",
    "duke_lesions_radiomic_medsam",
    dataset_type="duke_medsam",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["AMBL_medsam_ER"] = train(
    FILE_PATH / "ambl_lesions_radiomic_medsam_binary.csv",
    "ambl_lesions_radiomic_medsam_binary",
    dataset_type="ambl_medsam",
    tipo_fold= TIPO_FOLD,
    balance_test=BALANCE_TEST
)
# Stampa risultati finali
print("\n" + "="*80)
print("RIEPILOGO FINALE")
print("="*80)

for name, res in results.items():
    print(f"\nDataset: {res['dataset']}")
    print("-" * 80)
    print(f" Target: {res['target']}")
    print(f"  F1-score         = {res['mean_f1']:.3f}  ±  {res['std_f1']:.3f}")
    print(f"  Accuracy         = {res['mean_acc']:.3f}  ±  {res['std_acc']:.3f}")
    print(f"  Balanced Acc     = {res['mean_bal_acc']:.3f}  ±  {res['std_bal_acc']:.3f}") 
    print(f"  AUC              = {res['mean_auc']:.3f}  ±  {res['std_auc']:.3f}")


rows = []

for name, res in results.items():
    row = {
        "experiment": name,
        "dataset": res["dataset"],
        "target": res["target"],
        "mean_f1": round(res["mean_f1"], 3),
        "std_f1": round(res["std_f1"], 3),
        "mean_accuracy": round(res["mean_acc"], 3),
        "std_accuracy": round(res["std_acc"], 3),
        "mean_balanced_accuracy": round(res["mean_bal_acc"], 3),
        "std_balanced_accuracy": round(res["std_bal_acc"], 3),
        "mean_auc": round(res["mean_auc"], 3),
        "std_auc": round(res["std_auc"], 3)
    }
    rows.append(row)

df_er = pd.DataFrame(rows)

output_path = "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/rf_singolo.csv"
df_er.to_csv(output_path, index=False)

print(f"\nRisultati ER salvati in:\n{output_path}")
# Out:
# ================================================================================
# PROCESSING: duke_lesions (duke)
# ================================================================================
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.801733
# 1   DUKE_002   0   0     0                   0.595658
# 2   DUKE_005   1   0     1                   0.668824
# 3   DUKE_009   0   0     0                   0.680040
# 4   DUKE_010   0   0     0                   0.834884
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.727559                       17.331697
# 1                 0.262276                        6.491191
# 2                 0.462387                       18.682327
# 3                 0.543040                       16.896138
# 4                 0.566383                       22.952884
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       23.821699                               25.319289
# 1                       24.749465                               20.904455
# 2                       40.404115                               51.841254
# 3                       31.113997                               28.016591
# 4                       40.525347                               50.560680
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            27.939877  ...
# 1                            21.252044  ...
# 2                            49.529190  ...
# 3                            36.591695  ...
# 4                            49.711593  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       3.732730
# 1                                     816.019370
# 2                                      24.591161
# 3                                     507.049417
# 4                                    1695.066486
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.321169                    4.061870
# 1                                      0.002873                    6.566824
# 2                                      0.021288                    5.231952
# 3                                      0.001624                    6.788824
# 4                                      0.000581                    7.187445
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.019125                179288.204509
# 1                       0.476051                     8.279447
# 2                       0.037024                136797.383788
# 3                       0.307036                   191.988909
# 4                       0.505931                     7.282137
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                80.990253                   0.000911
# 1                 0.083176                   0.005217
# 2                24.588400                   0.000402
# 3                 0.408520                   0.000801
# 4                 0.736427                   0.000257
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   4.067385                 0.012786                 0.009999
# 1                3783.314508                 0.137734                 6.453010
# 2                  30.002001                 0.011011                 0.023444
# 3                6284.873277                 0.024907                 3.957295
# 4               11644.354499                 0.143078                 0.766544
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# Distribuzione target:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.801733                 0.727559
# 1                   0.595658                 0.262276
# 2                   0.668824                 0.462387
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       17.331697                       23.821699
# 1                        6.491191                       24.749465
# 2                       18.682327                       40.404115
#
#    original_shape_Maximum2DDiameterColumn
# 0                               25.319289
# 1                               20.904455
# 2                               51.841254
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#
#  Features: 105 colonne
#  Campioni: 291
#  Pazienti: 291
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=25, Classe 1=34, Totale=59
#   DOPO   - Test: Classe 0=25, Classe 1=25, Totale=50
#            Train: 232 → 241 (+9 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=25, Classe 1=33, Totale=58
#   DOPO   - Test: Classe 0=25, Classe 1=25, Totale=50
#            Train: 233 → 241 (+8 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=25, Classe 1=33, Totale=58
#   DOPO   - Test: Classe 0=25, Classe 1=25, Totale=50
#            Train: 233 → 241 (+8 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=24, Classe 1=34, Totale=58
#   DOPO   - Test: Classe 0=24, Classe 1=24, Totale=48
#            Train: 233 → 243 (+10 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=24, Classe 1=34, Totale=58
#   DOPO   - Test: Classe 0=24, Classe 1=24, Totale=48
#            Train: 233 → 243 (+10 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5763
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 8 17]
#  [ 8 17]]
#
#   TN=8 | FP=17 | FN=8 | TP=17
#   Classe 0: 8/25 corretti (32.0%)
#   Classe 1: 17/25 corretti (68.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      0.32      0.39        25
#            1       0.50      0.68      0.58        25
#
#     accuracy                           0.50        50
#    macro avg       0.50      0.50      0.48        50
# weighted avg       0.50      0.50      0.48        50
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6452
#   Accuracy:          0.5600
#   Balanced Accuracy: 0.5600
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 8 17]
#  [ 5 20]]
#
#   TN=8 | FP=17 | FN=5 | TP=20
#   Classe 0: 8/25 corretti (32.0%)
#   Classe 1: 20/25 corretti (80.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.62      0.32      0.42        25
#            1       0.54      0.80      0.65        25
#
#     accuracy                           0.56        50
#    macro avg       0.58      0.56      0.53        50
# weighted avg       0.58      0.56      0.53        50
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5517
#   Accuracy:          0.4800
#   Balanced Accuracy: 0.4800
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 8 17]
#  [ 9 16]]
#
#   TN=8 | FP=17 | FN=9 | TP=16
#   Classe 0: 8/25 corretti (32.0%)
#   Classe 1: 16/25 corretti (64.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.47      0.32      0.38        25
#            1       0.48      0.64      0.55        25
#
#     accuracy                           0.48        50
#    macro avg       0.48      0.48      0.47        50
# weighted avg       0.48      0.48      0.47        50
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6667
#   Accuracy:          0.5833
#   Balanced Accuracy: 0.5833
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 8 16]
#  [ 4 20]]
#
#   TN=8 | FP=16 | FN=4 | TP=20
#   Classe 0: 8/24 corretti (33.3%)
#   Classe 1: 20/24 corretti (83.3%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44        24
#            1       0.56      0.83      0.67        24
#
#     accuracy                           0.58        48
#    macro avg       0.61      0.58      0.56        48
# weighted avg       0.61      0.58      0.56        48
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.7037
#   Accuracy:          0.6667
#   Balanced Accuracy: 0.6667
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[13 11]
#  [ 5 19]]
#
#   TN=13 | FP=11 | FN=5 | TP=19
#   Classe 0: 13/24 corretti (54.2%)
#   Classe 1: 19/24 corretti (79.2%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.72      0.54      0.62        24
#            1       0.63      0.79      0.70        24
#
#     accuracy                           0.67        48
#    macro avg       0.68      0.67      0.66        48
# weighted avg       0.68      0.67      0.66        48
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.5763       0.5000       0.5000       0.5168
# 2        0.6452       0.5600       0.5600       0.4752
# 3        0.5517       0.4800       0.4800       0.4720
# 4        0.6667       0.5833       0.5833       0.5469
# 5        0.7037       0.6667       0.6667       0.6649
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.6287       0.5580       0.5580       0.5352
# Std      0.0566       0.0662       0.0662       0.0706
# ================================================================================
#
#
# ================================================================================
# PROCESSING: ambl_lesions_binary (ambl)
# ================================================================================
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.528082
# 1   AMBL-001         0         0           0                   0.336182
# 2   AMBL-003         0         0           0                   0.563923
# 3   AMBL-005         1         1           0                   0.761755
# 4   AMBL-007         1         0           0                   0.557584
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.375975                        8.551139
# 1                 0.293785                        7.651833
# 2                 0.394181                        8.781372
# 3                 0.641036                       20.245467
# 4                 0.366074                       18.597143
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.743875                               16.077739
# 1                       26.045677                               12.776208
# 2                       22.277510                               15.791279
# 3                       31.582394                               31.583382
# 4                       50.801628                               39.257160
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            26.863471  ...
# 1                            29.951350  ...
# 2                            22.006371  ...
# 3                            37.458189  ...
# 4                            60.793912  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      16.098904
# 1                                      10.777727
# 2                                       8.196991
# 3                                      28.274242
# 4                                       5.980941
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.043716                    4.536604
# 1                                      0.029528                    4.817406
# 2                                      0.075240                    5.007601
# 3                                      0.025064                    5.871338
# 4                                      0.067983                    4.739166
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.064252                  5792.756564
# 1                       0.093978                  1267.861250
# 2                       0.178138                   126.100723
# 3                       0.063874                  9578.078205
# 4                       0.031371                 91434.782971
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 2.775213                   0.005173
# 1                 2.353315                   0.007040
# 2                 2.067157                   0.011244
# 3                 6.402052                   0.001304
# 4                28.501489                   0.000872
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  19.975703                 0.014182                 0.183764
# 1                  25.004753                 0.040598                 0.210906
# 2                  24.083142                 0.051274                 0.292125
# 3                  91.217734                 0.049171                 0.116650
# 4                   9.737002                 0.018303                 0.016016
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# Distribuzione target:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.528082                 0.375975
# 1                   0.336182                 0.293785
# 2                   0.563923                 0.394181
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.551139                       22.743875
# 1                        7.651833                       26.045677
# 2                        8.781372                       22.277510
#
#    original_shape_Maximum2DDiameterColumn
# 0                               16.077739
# 1                               12.776208
# 2                               15.791279
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#
#  Features: 105 colonne
#  Campioni: 82
#  Pazienti: 70
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=7, Classe 1=10, Totale=17
#   DOPO   - Test: Classe 0=7, Classe 1=7, Totale=14
#            Train: 65 → 68 (+3 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=7, Classe 1=10, Totale=17
#   DOPO   - Test: Classe 0=7, Classe 1=7, Totale=14
#            Train: 65 → 68 (+3 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=6, Classe 1=10, Totale=16
#   DOPO   - Test: Classe 0=6, Classe 1=6, Totale=12
#            Train: 66 → 70 (+4 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=6, Classe 1=10, Totale=16
#   DOPO   - Test: Classe 0=6, Classe 1=6, Totale=12
#            Train: 66 → 70 (+4 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=6, Classe 1=10, Totale=16
#   DOPO   - Test: Classe 0=6, Classe 1=6, Totale=12
#            Train: 66 → 70 (+4 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6667
#   Accuracy:          0.5714
#   Balanced Accuracy: 0.5714
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[2 5]
#  [1 6]]
#
#   TN=2 | FP=5 | FN=1 | TP=6
#   Classe 0: 2/7 corretti (28.6%)
#   Classe 1: 6/7 corretti (85.7%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.55      0.86      0.67         7
#
#     accuracy                           0.57        14
#    macro avg       0.61      0.57      0.53        14
# weighted avg       0.61      0.57      0.53        14
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.7368
#   Accuracy:          0.6429
#   Balanced Accuracy: 0.6429
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[2 5]
#  [0 7]]
#
#   TN=2 | FP=5 | FN=0 | TP=7
#   Classe 0: 2/7 corretti (28.6%)
#   Classe 1: 7/7 corretti (100.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.44         7
#            1       0.58      1.00      0.74         7
#
#     accuracy                           0.64        14
#    macro avg       0.79      0.64      0.59        14
# weighted avg       0.79      0.64      0.59        14
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6250
#   Accuracy:          0.5000
#   Balanced Accuracy: 0.5000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[1 5]
#  [1 5]]
#
#   TN=1 | FP=5 | FN=1 | TP=5
#   Classe 0: 1/6 corretti (16.7%)
#   Classe 1: 5/6 corretti (83.3%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25         6
#            1       0.50      0.83      0.62         6
#
#     accuracy                           0.50        12
#    macro avg       0.50      0.50      0.44        12
# weighted avg       0.50      0.50      0.44        12
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5455
#   Accuracy:          0.5833
#   Balanced Accuracy: 0.5833
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[4 2]
#  [3 3]]
#
#   TN=4 | FP=2 | FN=3 | TP=3
#   Classe 0: 4/6 corretti (66.7%)
#   Classe 1: 3/6 corretti (50.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.60      0.50      0.55         6
#
#     accuracy                           0.58        12
#    macro avg       0.59      0.58      0.58        12
# weighted avg       0.59      0.58      0.58        12
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.7692
#   Accuracy:          0.7500
#   Balanced Accuracy: 0.7500
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[4 2]
#  [1 5]]
#
#   TN=4 | FP=2 | FN=1 | TP=5
#   Classe 0: 4/6 corretti (66.7%)
#   Classe 1: 5/6 corretti (83.3%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.71      0.83      0.77         6
#
#     accuracy                           0.75        12
#    macro avg       0.76      0.75      0.75        12
# weighted avg       0.76      0.75      0.75        12
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.6667       0.5714       0.5714       0.5306
# 2        0.7368       0.6429       0.6429       0.8571
# 3        0.6250       0.5000       0.5000       0.4722
# 4        0.5455       0.5833       0.5833       0.5556
# 5        0.7692       0.7500       0.7500       0.8333
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.6686       0.6095       0.6095       0.6498
# Std      0.0798       0.0836       0.0836       0.1620
# ================================================================================
#
#
# ================================================================================
# PROCESSING: duke_lesions_radiomic_medsam (duke_medsam)
# ================================================================================
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.956109
# 1   DUKE_002   0   0     0                   0.986617
# 2   DUKE_005   1   0     1                   0.531310
# 3   DUKE_009   0   0     0                   0.985995
# 4   DUKE_010   0   0     0                   0.913163
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.844657                       23.236690
# 1                 0.738184                       14.124854
# 2                 0.362991                       19.074218
# 3                 0.907380                       29.586478
# 4                 0.666651                       31.984526
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       27.510206                               33.841165
# 1                       19.134592                               21.804053
# 2                       52.547304                               55.177634
# 3                       32.606481                               40.022114
# 4                       47.977885                               60.524767
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            37.070079  ...
# 1                            25.679582  ...
# 2                            50.896657  ...
# 3                            42.657348  ...
# 4                            59.510315  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       4.065512
# 1                                     513.886736
# 2                                      20.795057
# 3                                     329.788184
# 4                                     938.945662
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.290643                    4.242751
# 1                                      0.013580                    7.206688
# 2                                      0.036582                    5.452188
# 3                                      0.004940                    7.262605
# 4                                      0.005418                    7.535492
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.017641                329513.249683
# 1                       0.507470                     9.310223
# 2                       0.039666                135505.922314
# 3                       0.301114                   212.257020
# 4                       0.569700                     4.200472
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0               116.318648                   0.000533
# 1                 0.471680                   0.002271
# 2                34.962085                   0.000325
# 3                 1.345384                   0.000424
# 4                 2.730941                   0.000165
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   7.410763                 0.012685                 0.010819
# 1                4216.436213                 0.432867                 3.156365
# 2                  30.408779                 0.017395                 0.016335
# 3                4459.712477                 0.074034                 1.055925
# 4               10483.944265                 0.453141                 0.369774
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# Distribuzione target:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke_medsam): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.956109                 0.844657
# 1                   0.986617                 0.738184
# 2                   0.531310                 0.362991
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       23.236690                       27.510206
# 1                       14.124854                       19.134592
# 2                       19.074218                       52.547304
#
#    original_shape_Maximum2DDiameterColumn
# 0                               33.841165
# 1                               21.804053
# 2                               55.177634
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#
#  Features: 105 colonne
#  Campioni: 291
#  Pazienti: 291
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=25, Classe 1=34, Totale=59
#   DOPO   - Test: Classe 0=25, Classe 1=25, Totale=50
#            Train: 232 → 241 (+9 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=25, Classe 1=33, Totale=58
#   DOPO   - Test: Classe 0=25, Classe 1=25, Totale=50
#            Train: 233 → 241 (+8 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=25, Classe 1=33, Totale=58
#   DOPO   - Test: Classe 0=25, Classe 1=25, Totale=50
#            Train: 233 → 241 (+8 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=24, Classe 1=34, Totale=58
#   DOPO   - Test: Classe 0=24, Classe 1=24, Totale=48
#            Train: 233 → 243 (+10 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=24, Classe 1=34, Totale=58
#   DOPO   - Test: Classe 0=24, Classe 1=24, Totale=48
#            Train: 233 → 243 (+10 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6429
#   Accuracy:          0.6000
#   Balanced Accuracy: 0.6000
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[12 13]
#  [ 7 18]]
#
#   TN=12 | FP=13 | FN=7 | TP=18
#   Classe 0: 12/25 corretti (48.0%)
#   Classe 1: 18/25 corretti (72.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.63      0.48      0.55        25
#            1       0.58      0.72      0.64        25
#
#     accuracy                           0.60        50
#    macro avg       0.61      0.60      0.59        50
# weighted avg       0.61      0.60      0.59        50
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6349
#   Accuracy:          0.5400
#   Balanced Accuracy: 0.5400
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 7 18]
#  [ 5 20]]
#
#   TN=7 | FP=18 | FN=5 | TP=20
#   Classe 0: 7/25 corretti (28.0%)
#   Classe 1: 20/25 corretti (80.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.58      0.28      0.38        25
#            1       0.53      0.80      0.63        25
#
#     accuracy                           0.54        50
#    macro avg       0.55      0.54      0.51        50
# weighted avg       0.55      0.54      0.51        50
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6349
#   Accuracy:          0.5400
#   Balanced Accuracy: 0.5400
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 7 18]
#  [ 5 20]]
#
#   TN=7 | FP=18 | FN=5 | TP=20
#   Classe 0: 7/25 corretti (28.0%)
#   Classe 1: 20/25 corretti (80.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.58      0.28      0.38        25
#            1       0.53      0.80      0.63        25
#
#     accuracy                           0.54        50
#    macro avg       0.55      0.54      0.51        50
# weighted avg       0.55      0.54      0.51        50
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6071
#   Accuracy:          0.5417
#   Balanced Accuracy: 0.5417
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 9 15]
#  [ 7 17]]
#
#   TN=9 | FP=15 | FN=7 | TP=17
#   Classe 0: 9/24 corretti (37.5%)
#   Classe 1: 17/24 corretti (70.8%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.56      0.38      0.45        24
#            1       0.53      0.71      0.61        24
#
#     accuracy                           0.54        48
#    macro avg       0.55      0.54      0.53        48
# weighted avg       0.55      0.54      0.53        48
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5357
#   Accuracy:          0.4583
#   Balanced Accuracy: 0.4583
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 7 17]
#  [ 9 15]]
#
#   TN=7 | FP=17 | FN=9 | TP=15
#   Classe 0: 7/24 corretti (29.2%)
#   Classe 1: 15/24 corretti (62.5%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.44      0.29      0.35        24
#            1       0.47      0.62      0.54        24
#
#     accuracy                           0.46        48
#    macro avg       0.45      0.46      0.44        48
# weighted avg       0.45      0.46      0.44        48
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.6429       0.6000       0.6000       0.5264
# 2        0.6349       0.5400       0.5400       0.5136
# 3        0.6349       0.5400       0.5400       0.5984
# 4        0.6071       0.5417       0.5417       0.5573
# 5        0.5357       0.4583       0.4583       0.5000
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.6111       0.5360       0.5360       0.5391
# Std      0.0396       0.0451       0.0451       0.0352
# ================================================================================
#
#
# ================================================================================
# PROCESSING: ambl_lesions_radiomic_medsam_binary (ambl_medsam)
# ================================================================================
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.632264
# 1   AMBL-001         0         0           0                   0.428066
# 2   AMBL-003         0         0           0                   0.853921
# 3   AMBL-005         1         1           0                   0.803782
# 4   AMBL-007         1         0           0                   0.631452
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.574573                       16.587860
# 1                 0.294263                       10.065943
# 2                 0.435016                        9.836007
# 3                 0.374899                       15.587523
# 4                 0.391559                       23.460339
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       28.869904                               22.120222
# 1                       34.207348                               17.412966
# 2                       22.610678                               21.247525
# 3                       41.577953                               34.491247
# 4                       59.915195                               44.173008
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            35.666937  ...
# 1                            36.743872  ...
# 2                            27.346457  ...
# 3                            42.427943  ...
# 4                            61.891243  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      11.866752
# 1                                       6.358452
# 2                                       8.132437
# 3                                      34.881141
# 4                                       5.821488
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.088645                    5.405028
# 1                                      0.055140                    5.483128
# 2                                      0.081316                    5.020232
# 3                                      0.025796                    5.568237
# 4                                      0.135345                    5.439009
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.043620                 17397.502279
# 1                       0.049725                  7036.435472
# 2                       0.054954                  4691.632692
# 3                       0.184971                   967.852818
# 4                       0.025776                106222.332082
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                13.115490                   0.001677
# 1                10.744731                   0.002468
# 2                 8.450972                   0.003567
# 3                 3.433053                   0.002188
# 4                57.721284                   0.000612
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  20.634441                 0.046452                 0.043755
# 1                  25.761844                 0.065802                 0.062361
# 2                  22.650386                 0.048524                 0.099512
# 3                 117.475529                 0.103989                 0.173719
# 4                  11.824437                 0.029061                 0.015007
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# Distribuzione target:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl_medsam): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.632264                 0.574573
# 1                   0.428066                 0.294263
# 2                   0.853921                 0.435016
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       16.587860                       28.869904
# 1                       10.065943                       34.207348
# 2                        9.836007                       22.610678
#
#    original_shape_Maximum2DDiameterColumn
# 0                               22.120222
# 1                               17.412966
# 2                               21.247525
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#
#  Features: 105 colonne
#  Campioni: 82
#  Pazienti: 70
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=7, Classe 1=10, Totale=17
#   DOPO   - Test: Classe 0=7, Classe 1=7, Totale=14
#            Train: 65 → 68 (+3 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=7, Classe 1=10, Totale=17
#   DOPO   - Test: Classe 0=7, Classe 1=7, Totale=14
#            Train: 65 → 68 (+3 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=6, Classe 1=10, Totale=16
#   DOPO   - Test: Classe 0=6, Classe 1=6, Totale=12
#            Train: 66 → 70 (+4 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=6, Classe 1=10, Totale=16
#   DOPO   - Test: Classe 0=6, Classe 1=6, Totale=12
#            Train: 66 → 70 (+4 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=6, Classe 1=10, Totale=16
#   DOPO   - Test: Classe 0=6, Classe 1=6, Totale=12
#            Train: 66 → 70 (+4 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.7368
#   Accuracy:          0.6429
#   Balanced Accuracy: 0.6429
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[2 5]
#  [0 7]]
#
#   TN=2 | FP=5 | FN=0 | TP=7
#   Classe 0: 2/7 corretti (28.6%)
#   Classe 1: 7/7 corretti (100.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.44         7
#            1       0.58      1.00      0.74         7
#
#     accuracy                           0.64        14
#    macro avg       0.79      0.64      0.59        14
# weighted avg       0.79      0.64      0.59        14
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.7778
#   Accuracy:          0.7143
#   Balanced Accuracy: 0.7143
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 4]
#  [0 7]]
#
#   TN=3 | FP=4 | FN=0 | TP=7
#   Classe 0: 3/7 corretti (42.9%)
#   Classe 1: 7/7 corretti (100.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.64      1.00      0.78         7
#
#     accuracy                           0.71        14
#    macro avg       0.82      0.71      0.69        14
# weighted avg       0.82      0.71      0.69        14
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.8000
#   Accuracy:          0.7500
#   Balanced Accuracy: 0.7500
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[3 3]
#  [0 6]]
#
#   TN=3 | FP=3 | FN=0 | TP=6
#   Classe 0: 3/6 corretti (50.0%)
#   Classe 1: 6/6 corretti (100.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.67      1.00      0.80         6
#
#     accuracy                           0.75        12
#    macro avg       0.83      0.75      0.73        12
# weighted avg       0.83      0.75      0.73        12
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.5455
#   Accuracy:          0.5833
#   Balanced Accuracy: 0.5833
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[4 2]
#  [3 3]]
#
#   TN=4 | FP=2 | FN=3 | TP=3
#   Classe 0: 4/6 corretti (66.7%)
#   Classe 1: 3/6 corretti (50.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.60      0.50      0.55         6
#
#     accuracy                           0.58        12
#    macro avg       0.59      0.58      0.58        12
# weighted avg       0.59      0.58      0.58        12
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.9231
#   Accuracy:          0.9167
#   Balanced Accuracy: 0.9167
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[5 1]
#  [0 6]]
#
#   TN=5 | FP=1 | FN=0 | TP=6
#   Classe 0: 5/6 corretti (83.3%)
#   Classe 1: 6/6 corretti (100.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.86      1.00      0.92         6
#
#     accuracy                           0.92        12
#    macro avg       0.93      0.92      0.92        12
# weighted avg       0.93      0.92      0.92        12
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.7368       0.6429       0.6429       0.7755
# 2        0.7778       0.7143       0.7143       0.8673
# 3        0.8000       0.7500       0.7500       0.7222
# 4        0.5455       0.5833       0.5833       0.4722
# 5        0.9231       0.9167       0.9167       0.8333
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.7566       0.7214       0.7214       0.7341
# Std      0.1225       0.1133       0.1133       0.1400
# ================================================================================
#
#
# ================================================================================
# RIEPILOGO FINALE
# ================================================================================
#
# Dataset: duke_lesions
# --------------------------------------------------------------------------------
#  Target: ER
#   F1-score         = 0.629  ±  0.057
#   Accuracy         = 0.558  ±  0.066
#   Balanced Acc     = 0.558  ±  0.066
#   AUC              = 0.535  ±  0.071
#
# Dataset: ambl_lesions_binary
# --------------------------------------------------------------------------------
#  Target: ER [SII]
#   F1-score         = 0.669  ±  0.080
#   Accuracy         = 0.610  ±  0.084
#   Balanced Acc     = 0.610  ±  0.084
#   AUC              = 0.650  ±  0.162
#
# Dataset: duke_lesions_radiomic_medsam
# --------------------------------------------------------------------------------
#  Target: ER
#   F1-score         = 0.611  ±  0.040
#   Accuracy         = 0.536  ±  0.045
#   Balanced Acc     = 0.536  ±  0.045
#   AUC              = 0.539  ±  0.035
#
# Dataset: ambl_lesions_radiomic_medsam_binary
# --------------------------------------------------------------------------------
#  Target: ER [SII]
#   F1-score         = 0.757  ±  0.122
#   Accuracy         = 0.721  ±  0.113
#   Balanced Acc     = 0.721  ±  0.113
#   AUC              = 0.734  ±  0.140
#
# Risultati ER salvati in:
# /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/rf_singolo.csv

# %% [markdown]
# # Esecuzione Feature Importance

# %%
print("\n" + "="*80)
print("CALCOLO FEATURE IMPORTANCE (XGBoost - ER)")
print("="*80)

# DUKE
print("\n>>> FEATURE IMPORTANCE DUKE")

best_params_fi = results["DUKE_ER"]["best_params"]

df_fi = load_dataset(
    FILE_PATH / "duke_lesions.csv",
    "duke_lesions"
)

df_fi, y_fi = select_target(df_fi, TARGET_MAP["duke"])
X_fi, _ = build_features_and_groups(df_fi, TARGET_MAP["duke"], "duke")

model_fi = get_model(best_params_fi)
model_fi.fit(X_fi, y_fi)

fi_df = get_feature_importance(model_fi, X_fi.columns)

save_feature_importance(
    fi_df,
    "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_DUKE_ER.csv",
    top_n=20
)

# AMBL
print("\n>>> FEATURE IMPORTANCE AMBL")

best_params_fi = results["AMBL_ER"]["best_params"]

df_fi = load_dataset(
    FILE_PATH / "ambl_lesions_binary.csv",
    "ambl_lesions_binary"
)

df_fi, y_fi = select_target(df_fi, TARGET_MAP["ambl"])
X_fi, _ = build_features_and_groups(df_fi, TARGET_MAP["ambl"], "ambl")

model_fi = get_model(best_params_fi)
model_fi.fit(X_fi, y_fi)

fi_df = get_feature_importance(model_fi, X_fi.columns)

save_feature_importance(
    fi_df,
    "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_AMBL_ER.csv",
    top_n=20
)


# AMBL-medsam
print("\n>>> FEATURE IMPORTANCE AMBL")

best_params_fi = results["AMBL_medsam_ER"]["best_params"]

df_fi = load_dataset(
    FILE_PATH / "ambl_lesions_radiomic_medsam_binary.csv",
    "ambl_lesions_radiomic_medsam_binary"
)

df_fi, y_fi = select_target(df_fi, TARGET_MAP["ambl"])
X_fi, _ = build_features_and_groups(df_fi, TARGET_MAP["ambl"], "ambl")

model_fi = get_model(best_params_fi)
model_fi.fit(X_fi, y_fi)

fi_df = get_feature_importance(model_fi, X_fi.columns)

save_feature_importance(
    fi_df,
    "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_AMBL_ER_medsam.csv",
    top_n=20
)

# DUKE-medsam
print("\n>>> FEATURE IMPORTANCE DUKE")

best_params_fi = results["DUKE_medsam_ER"]["best_params"]

df_fi = load_dataset(
    FILE_PATH / "duke_lesions_radiomic_medsam.csv",
    "duke_lesions_radiomic_medsam"
)


df_fi, y_fi = select_target(df_fi, TARGET_MAP["duke"])
X_fi, _ = build_features_and_groups(df_fi, TARGET_MAP["duke"], "duke")

model_fi = get_model(best_params_fi)
model_fi.fit(X_fi, y_fi)

fi_df = get_feature_importance(model_fi, X_fi.columns)

save_feature_importance(
    fi_df,
    "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_DUKE_ER_medsam.csv",
    top_n=20
)
# Out:
# ================================================================================
# CALCOLO FEATURE IMPORTANCE (XGBoost - ER)
# ================================================================================
#
# >>> FEATURE IMPORTANCE DUKE
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.801733
# 1   DUKE_002   0   0     0                   0.595658
# 2   DUKE_005   1   0     1                   0.668824
# 3   DUKE_009   0   0     0                   0.680040
# 4   DUKE_010   0   0     0                   0.834884
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.727559                       17.331697
# 1                 0.262276                        6.491191
# 2                 0.462387                       18.682327
# 3                 0.543040                       16.896138
# 4                 0.566383                       22.952884
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       23.821699                               25.319289
# 1                       24.749465                               20.904455
# 2                       40.404115                               51.841254
# 3                       31.113997                               28.016591
# 4                       40.525347                               50.560680
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            27.939877  ...
# 1                            21.252044  ...
# 2                            49.529190  ...
# 3                            36.591695  ...
# 4                            49.711593  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       3.732730
# 1                                     816.019370
# 2                                      24.591161
# 3                                     507.049417
# 4                                    1695.066486
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.321169                    4.061870
# 1                                      0.002873                    6.566824
# 2                                      0.021288                    5.231952
# 3                                      0.001624                    6.788824
# 4                                      0.000581                    7.187445
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.019125                179288.204509
# 1                       0.476051                     8.279447
# 2                       0.037024                136797.383788
# 3                       0.307036                   191.988909
# 4                       0.505931                     7.282137
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                80.990253                   0.000911
# 1                 0.083176                   0.005217
# 2                24.588400                   0.000402
# 3                 0.408520                   0.000801
# 4                 0.736427                   0.000257
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   4.067385                 0.012786                 0.009999
# 1                3783.314508                 0.137734                 6.453010
# 2                  30.002001                 0.011011                 0.023444
# 3                6284.873277                 0.024907                 3.957295
# 4               11644.354499                 0.143078                 0.766544
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.801733                 0.727559
# 1                   0.595658                 0.262276
# 2                   0.668824                 0.462387
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       17.331697                       23.821699
# 1                        6.491191                       24.749465
# 2                       18.682327                       40.404115
#
#    original_shape_Maximum2DDiameterColumn
# 0                               25.319289
# 1                               20.904455
# 2                               51.841254
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#  Salvate top-20 feature in: /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_DUKE_ER.csv
#
# >>> FEATURE IMPORTANCE AMBL
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.528082
# 1   AMBL-001         0         0           0                   0.336182
# 2   AMBL-003         0         0           0                   0.563923
# 3   AMBL-005         1         1           0                   0.761755
# 4   AMBL-007         1         0           0                   0.557584
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.375975                        8.551139
# 1                 0.293785                        7.651833
# 2                 0.394181                        8.781372
# 3                 0.641036                       20.245467
# 4                 0.366074                       18.597143
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.743875                               16.077739
# 1                       26.045677                               12.776208
# 2                       22.277510                               15.791279
# 3                       31.582394                               31.583382
# 4                       50.801628                               39.257160
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            26.863471  ...
# 1                            29.951350  ...
# 2                            22.006371  ...
# 3                            37.458189  ...
# 4                            60.793912  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      16.098904
# 1                                      10.777727
# 2                                       8.196991
# 3                                      28.274242
# 4                                       5.980941
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.043716                    4.536604
# 1                                      0.029528                    4.817406
# 2                                      0.075240                    5.007601
# 3                                      0.025064                    5.871338
# 4                                      0.067983                    4.739166
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.064252                  5792.756564
# 1                       0.093978                  1267.861250
# 2                       0.178138                   126.100723
# 3                       0.063874                  9578.078205
# 4                       0.031371                 91434.782971
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 2.775213                   0.005173
# 1                 2.353315                   0.007040
# 2                 2.067157                   0.011244
# 3                 6.402052                   0.001304
# 4                28.501489                   0.000872
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  19.975703                 0.014182                 0.183764
# 1                  25.004753                 0.040598                 0.210906
# 2                  24.083142                 0.051274                 0.292125
# 3                  91.217734                 0.049171                 0.116650
# 4                   9.737002                 0.018303                 0.016016
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.528082                 0.375975
# 1                   0.336182                 0.293785
# 2                   0.563923                 0.394181
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.551139                       22.743875
# 1                        7.651833                       26.045677
# 2                        8.781372                       22.277510
#
#    original_shape_Maximum2DDiameterColumn
# 0                               16.077739
# 1                               12.776208
# 2                               15.791279
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#  Salvate top-20 feature in: /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_AMBL_ER.csv
#
# >>> FEATURE IMPORTANCE AMBL
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.632264
# 1   AMBL-001         0         0           0                   0.428066
# 2   AMBL-003         0         0           0                   0.853921
# 3   AMBL-005         1         1           0                   0.803782
# 4   AMBL-007         1         0           0                   0.631452
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.574573                       16.587860
# 1                 0.294263                       10.065943
# 2                 0.435016                        9.836007
# 3                 0.374899                       15.587523
# 4                 0.391559                       23.460339
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       28.869904                               22.120222
# 1                       34.207348                               17.412966
# 2                       22.610678                               21.247525
# 3                       41.577953                               34.491247
# 4                       59.915195                               44.173008
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            35.666937  ...
# 1                            36.743872  ...
# 2                            27.346457  ...
# 3                            42.427943  ...
# 4                            61.891243  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      11.866752
# 1                                       6.358452
# 2                                       8.132437
# 3                                      34.881141
# 4                                       5.821488
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.088645                    5.405028
# 1                                      0.055140                    5.483128
# 2                                      0.081316                    5.020232
# 3                                      0.025796                    5.568237
# 4                                      0.135345                    5.439009
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.043620                 17397.502279
# 1                       0.049725                  7036.435472
# 2                       0.054954                  4691.632692
# 3                       0.184971                   967.852818
# 4                       0.025776                106222.332082
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                13.115490                   0.001677
# 1                10.744731                   0.002468
# 2                 8.450972                   0.003567
# 3                 3.433053                   0.002188
# 4                57.721284                   0.000612
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  20.634441                 0.046452                 0.043755
# 1                  25.761844                 0.065802                 0.062361
# 2                  22.650386                 0.048524                 0.099512
# 3                 117.475529                 0.103989                 0.173719
# 4                  11.824437                 0.029061                 0.015007
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.632264                 0.574573
# 1                   0.428066                 0.294263
# 2                   0.853921                 0.435016
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       16.587860                       28.869904
# 1                       10.065943                       34.207348
# 2                        9.836007                       22.610678
#
#    original_shape_Maximum2DDiameterColumn
# 0                               22.120222
# 1                               17.412966
# 2                               21.247525
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#  Salvate top-20 feature in: /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_AMBL_ER_medsam.csv
#
# >>> FEATURE IMPORTANCE DUKE
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.956109
# 1   DUKE_002   0   0     0                   0.986617
# 2   DUKE_005   1   0     1                   0.531310
# 3   DUKE_009   0   0     0                   0.985995
# 4   DUKE_010   0   0     0                   0.913163
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.844657                       23.236690
# 1                 0.738184                       14.124854
# 2                 0.362991                       19.074218
# 3                 0.907380                       29.586478
# 4                 0.666651                       31.984526
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       27.510206                               33.841165
# 1                       19.134592                               21.804053
# 2                       52.547304                               55.177634
# 3                       32.606481                               40.022114
# 4                       47.977885                               60.524767
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            37.070079  ...
# 1                            25.679582  ...
# 2                            50.896657  ...
# 3                            42.657348  ...
# 4                            59.510315  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       4.065512
# 1                                     513.886736
# 2                                      20.795057
# 3                                     329.788184
# 4                                     938.945662
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.290643                    4.242751
# 1                                      0.013580                    7.206688
# 2                                      0.036582                    5.452188
# 3                                      0.004940                    7.262605
# 4                                      0.005418                    7.535492
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.017641                329513.249683
# 1                       0.507470                     9.310223
# 2                       0.039666                135505.922314
# 3                       0.301114                   212.257020
# 4                       0.569700                     4.200472
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0               116.318648                   0.000533
# 1                 0.471680                   0.002271
# 2                34.962085                   0.000325
# 3                 1.345384                   0.000424
# 4                 2.730941                   0.000165
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   7.410763                 0.012685                 0.010819
# 1                4216.436213                 0.432867                 3.156365
# 2                  30.408779                 0.017395                 0.016335
# 3                4459.712477                 0.074034                 1.055925
# 4               10483.944265                 0.453141                 0.369774
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.956109                 0.844657
# 1                   0.986617                 0.738184
# 2                   0.531310                 0.362991
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       23.236690                       27.510206
# 1                       14.124854                       19.134592
# 2                       19.074218                       52.547304
#
#    original_shape_Maximum2DDiameterColumn
# 0                               33.841165
# 1                               21.804053
# 2                               55.177634
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#  Salvate top-20 feature in: /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_DUKE_ER_medsam.csv

# %% [markdown]
# # Cross-validation tra dataset

# %%
def cross_validation(train_csv, train_name, train_type, test_csv, test_name, test_type, best_params, balance_test=False):
    print("\n" + "="*80)
    print("CROSS-DATASET VALIDATION")
    print("="*80)
    print(f"TRAIN: {train_name}")
    print(f"TEST : {test_name}")
    print("="*80)

    # Carico il csv di Training
    df_train = load_dataset(train_csv, train_name)
    target_train = TARGET_MAP[train_type]
    df_train, y_train = select_target(df_train, target_train)
    X_train, _ = build_features_and_groups(df_train, target_train, train_type)

    # Carico il csv di Testing
    df_test = load_dataset(test_csv, test_name)
    target_test = TARGET_MAP[test_type]
    df_test, y_test = select_target(df_test, target_test)
    X_test, _ = build_features_and_groups(df_test, target_test, test_type)

    # Allineamento feature
    common_cols = X_train.columns.intersection(X_test.columns)
    X_train = X_train[common_cols]
    X_test  = X_test[common_cols]

    print(f"\nFeature comuni utilizzate: {len(common_cols)}")

    # Alleno il modello sul TRAIN set
    model = get_model(best_params)
    model.fit(X_train, y_train)

    # ora test_idx punta correttamente al test set
    test_idx = np.arange(len(X_test))
    
    # Bilanciamento opzionale del test set
    if balance_test:
        # Creo uno split fittizio per riutilizzare la funzione di bilanciamento
        dummy_train = np.array([])  # Train vuoto, non serve
        splits = [(dummy_train, test_idx)]
        splits = balance_test_sets(splits, y_test)
        _, test_idx = splits[0]

    # Predizioni sul test set (bilanciato o meno)
    y_pred = model.predict(X_test.iloc[test_idx])
    y_prob = model.predict_proba(X_test.iloc[test_idx])[:,1]
    y_test_final = y_test.iloc[test_idx]

    # Metriche
    f1 = f1_score(y_test_final, y_pred, zero_division=0)
    acc = accuracy_score(y_test_final, y_pred)
    bal_acc = balanced_accuracy_score(y_test_final, y_pred)
    auc = roc_auc_score(y_test_final, y_prob)

    print("\n" + "-"*80)
    print("RISULTATI CROSS-DATASET")
    print("-"*80)
    print(f" F1-score          : {f1:.4f}")
    print(f" Accuracy          : {acc:.4f}")
    print(f" Balanced Accuracy : {bal_acc:.4f}")
    print(f" ROC-AUC           : {auc:.4f}")

    print("\nCONFUSION MATRIX")
    cm = confusion_matrix(y_test_final, y_pred)
    print(cm)

    print("\nCLASSIFICATION REPORT")
    print(classification_report(y_test_final, y_pred, zero_division=0))

    return {
        "train": train_name,
        "test": test_name,
        "balance_test": balance_test,
        "f1": f1,
        "acc": acc,
        "bal_acc": bal_acc,
        "auc": auc,
        "cm": cm
    }

# %%
def save_cross_results_to_csv(cross_results, output_path):
    """
    Salva (o aggiunge) i risultati della cross-dataset validation in CSV.
    """

    rows = []

    for exp_name, res in cross_results.items():
        row = {
            "experiment": exp_name,
            "train_dataset": res.get("train"),
            "test_dataset": res.get("test"),
            "balance_test": res.get("balance_test"),
            "f1": round(res.get("f1"), 3),
            "accuracy": round(res.get("acc"), 3),
            "balanced_accuracy": round(res.get("bal_acc"), 3),
            "auc": round(res.get("auc"), 3)
        }
        rows.append(row)

    df = pd.DataFrame(rows)

    file_exists = Path(output_path).exists()

    df.to_csv(
        output_path,
        mode="a" if file_exists else "w",
        header=not file_exists,
        index=False,
        float_format="%.3f"
    )

    print(f"\n Risultati cross-dataset aggiunti in:")
    print(output_path)

    return df

# %% [markdown]
# # Esecuzione

# %%
cross_results = {}

# Prendo i best params dalle CV intra-dataset
best_params_ambl = results["AMBL_ER"]["best_params"]
best_params_duke = results["DUKE_ER"]["best_params"]
best_params_ambl_medsam = results["AMBL_medsam_ER"]["best_params"]
best_params_duke_medsam = results["DUKE_medsam_ER"]["best_params"]

# ================================
# 1. AMBL → DUKE
# ================================
cross_results["AMBL_to_DUKE"] = cross_validation(
    FILE_PATH / "ambl_lesions_binary.csv",
    "ambl_lesions_binary",
    "ambl",
    FILE_PATH / "duke_lesions.csv",
    "duke_lesions",
    "duke",
    best_params_ambl,
    balance_test=BALANCE_TEST
)

# ================================
# 2. DUKE → AMBL
# ================================
cross_results["DUKE_to_AMBL"] = cross_validation(
    FILE_PATH / "duke_lesions.csv",
    "duke_lesions",
    "duke",
    FILE_PATH / "ambl_lesions_binary.csv",
    "ambl_lesions_binary",
    "ambl",
    best_params_duke,
    balance_test=BALANCE_TEST
)

# ================================
# 3. AMBL_medsam → DUKE_medsam
# ================================
cross_results["AMBL_medsam_to_DUKE_medsam"] = cross_validation(
    FILE_PATH / "ambl_lesions_radiomic_medsam_binary.csv",
    "ambl_lesions_radiomic_medsam_binary",
    "ambl_medsam",
    FILE_PATH / "duke_lesions_radiomic_medsam.csv",
    "duke_lesions_radiomic_medsam",
    "duke_medsam",
    best_params_ambl_medsam,
    balance_test=BALANCE_TEST
)

# ================================
# 4. DUKE_medsam → AMBL_medsam
# ================================
cross_results["DUKE_medsam_to_AMBL_medsam"] = cross_validation(
    FILE_PATH / "duke_lesions_radiomic_medsam.csv",
    "duke_lesions_radiomic_medsam",
    "duke_medsam",
    FILE_PATH / "ambl_lesions_radiomic_medsam_binary.csv",
    "ambl_lesions_radiomic_medsam_binary",
    "ambl_medsam",
    best_params_duke_medsam,
    balance_test=BALANCE_TEST
)

# Salva i risultati
save_cross_results_to_csv(
    cross_results,
    "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/cross_validation_rf.csv"
)
# Out:
# ================================================================================
# CROSS-DATASET VALIDATION
# ================================================================================
# TRAIN: ambl_lesions_binary
# TEST : duke_lesions
# ================================================================================
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.528082
# 1   AMBL-001         0         0           0                   0.336182
# 2   AMBL-003         0         0           0                   0.563923
# 3   AMBL-005         1         1           0                   0.761755
# 4   AMBL-007         1         0           0                   0.557584
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.375975                        8.551139
# 1                 0.293785                        7.651833
# 2                 0.394181                        8.781372
# 3                 0.641036                       20.245467
# 4                 0.366074                       18.597143
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.743875                               16.077739
# 1                       26.045677                               12.776208
# 2                       22.277510                               15.791279
# 3                       31.582394                               31.583382
# 4                       50.801628                               39.257160
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            26.863471  ...
# 1                            29.951350  ...
# 2                            22.006371  ...
# 3                            37.458189  ...
# 4                            60.793912  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      16.098904
# 1                                      10.777727
# 2                                       8.196991
# 3                                      28.274242
# 4                                       5.980941
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.043716                    4.536604
# 1                                      0.029528                    4.817406
# 2                                      0.075240                    5.007601
# 3                                      0.025064                    5.871338
# 4                                      0.067983                    4.739166
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.064252                  5792.756564
# 1                       0.093978                  1267.861250
# 2                       0.178138                   126.100723
# 3                       0.063874                  9578.078205
# 4                       0.031371                 91434.782971
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 2.775213                   0.005173
# 1                 2.353315                   0.007040
# 2                 2.067157                   0.011244
# 3                 6.402052                   0.001304
# 4                28.501489                   0.000872
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  19.975703                 0.014182                 0.183764
# 1                  25.004753                 0.040598                 0.210906
# 2                  24.083142                 0.051274                 0.292125
# 3                  91.217734                 0.049171                 0.116650
# 4                   9.737002                 0.018303                 0.016016
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.528082                 0.375975
# 1                   0.336182                 0.293785
# 2                   0.563923                 0.394181
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.551139                       22.743875
# 1                        7.651833                       26.045677
# 2                        8.781372                       22.277510
#
#    original_shape_Maximum2DDiameterColumn
# 0                               16.077739
# 1                               12.776208
# 2                               15.791279
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.801733
# 1   DUKE_002   0   0     0                   0.595658
# 2   DUKE_005   1   0     1                   0.668824
# 3   DUKE_009   0   0     0                   0.680040
# 4   DUKE_010   0   0     0                   0.834884
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.727559                       17.331697
# 1                 0.262276                        6.491191
# 2                 0.462387                       18.682327
# 3                 0.543040                       16.896138
# 4                 0.566383                       22.952884
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       23.821699                               25.319289
# 1                       24.749465                               20.904455
# 2                       40.404115                               51.841254
# 3                       31.113997                               28.016591
# 4                       40.525347                               50.560680
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            27.939877  ...
# 1                            21.252044  ...
# 2                            49.529190  ...
# 3                            36.591695  ...
# 4                            49.711593  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       3.732730
# 1                                     816.019370
# 2                                      24.591161
# 3                                     507.049417
# 4                                    1695.066486
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.321169                    4.061870
# 1                                      0.002873                    6.566824
# 2                                      0.021288                    5.231952
# 3                                      0.001624                    6.788824
# 4                                      0.000581                    7.187445
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.019125                179288.204509
# 1                       0.476051                     8.279447
# 2                       0.037024                136797.383788
# 3                       0.307036                   191.988909
# 4                       0.505931                     7.282137
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                80.990253                   0.000911
# 1                 0.083176                   0.005217
# 2                24.588400                   0.000402
# 3                 0.408520                   0.000801
# 4                 0.736427                   0.000257
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   4.067385                 0.012786                 0.009999
# 1                3783.314508                 0.137734                 6.453010
# 2                  30.002001                 0.011011                 0.023444
# 3                6284.873277                 0.024907                 3.957295
# 4               11644.354499                 0.143078                 0.766544
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.801733                 0.727559
# 1                   0.595658                 0.262276
# 2                   0.668824                 0.462387
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       17.331697                       23.821699
# 1                        6.491191                       24.749465
# 2                       18.682327                       40.404115
#
#    original_shape_Maximum2DDiameterColumn
# 0                               25.319289
# 1                               20.904455
# 2                               51.841254
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#
# Feature comuni utilizzate: 105
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=123, Classe 1=168, Totale=291
#   DOPO   - Test: Classe 0=123, Classe 1=123, Totale=246
#            Train: 0 → 45 (+45 campioni)
#
#  Split bilanciati creati con successo
#
#
# --------------------------------------------------------------------------------
# RISULTATI CROSS-DATASET
# --------------------------------------------------------------------------------
#  F1-score          : 0.3261
#  Accuracy          : 0.4959
#  Balanced Accuracy : 0.4959
#  ROC-AUC           : 0.4701
#
# CONFUSION MATRIX
# [[92 31]
#  [93 30]]
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60       123
#            1       0.49      0.24      0.33       123
#
#     accuracy                           0.50       246
#    macro avg       0.49      0.50      0.46       246
# weighted avg       0.49      0.50      0.46       246
#
#
# ================================================================================
# CROSS-DATASET VALIDATION
# ================================================================================
# TRAIN: duke_lesions
# TEST : ambl_lesions_binary
# ================================================================================
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.801733
# 1   DUKE_002   0   0     0                   0.595658
# 2   DUKE_005   1   0     1                   0.668824
# 3   DUKE_009   0   0     0                   0.680040
# 4   DUKE_010   0   0     0                   0.834884
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.727559                       17.331697
# 1                 0.262276                        6.491191
# 2                 0.462387                       18.682327
# 3                 0.543040                       16.896138
# 4                 0.566383                       22.952884
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       23.821699                               25.319289
# 1                       24.749465                               20.904455
# 2                       40.404115                               51.841254
# 3                       31.113997                               28.016591
# 4                       40.525347                               50.560680
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            27.939877  ...
# 1                            21.252044  ...
# 2                            49.529190  ...
# 3                            36.591695  ...
# 4                            49.711593  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       3.732730
# 1                                     816.019370
# 2                                      24.591161
# 3                                     507.049417
# 4                                    1695.066486
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.321169                    4.061870
# 1                                      0.002873                    6.566824
# 2                                      0.021288                    5.231952
# 3                                      0.001624                    6.788824
# 4                                      0.000581                    7.187445
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.019125                179288.204509
# 1                       0.476051                     8.279447
# 2                       0.037024                136797.383788
# 3                       0.307036                   191.988909
# 4                       0.505931                     7.282137
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                80.990253                   0.000911
# 1                 0.083176                   0.005217
# 2                24.588400                   0.000402
# 3                 0.408520                   0.000801
# 4                 0.736427                   0.000257
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   4.067385                 0.012786                 0.009999
# 1                3783.314508                 0.137734                 6.453010
# 2                  30.002001                 0.011011                 0.023444
# 3                6284.873277                 0.024907                 3.957295
# 4               11644.354499                 0.143078                 0.766544
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.801733                 0.727559
# 1                   0.595658                 0.262276
# 2                   0.668824                 0.462387
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       17.331697                       23.821699
# 1                        6.491191                       24.749465
# 2                       18.682327                       40.404115
#
#    original_shape_Maximum2DDiameterColumn
# 0                               25.319289
# 1                               20.904455
# 2                               51.841254
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.528082
# 1   AMBL-001         0         0           0                   0.336182
# 2   AMBL-003         0         0           0                   0.563923
# 3   AMBL-005         1         1           0                   0.761755
# 4   AMBL-007         1         0           0                   0.557584
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.375975                        8.551139
# 1                 0.293785                        7.651833
# 2                 0.394181                        8.781372
# 3                 0.641036                       20.245467
# 4                 0.366074                       18.597143
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.743875                               16.077739
# 1                       26.045677                               12.776208
# 2                       22.277510                               15.791279
# 3                       31.582394                               31.583382
# 4                       50.801628                               39.257160
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            26.863471  ...
# 1                            29.951350  ...
# 2                            22.006371  ...
# 3                            37.458189  ...
# 4                            60.793912  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      16.098904
# 1                                      10.777727
# 2                                       8.196991
# 3                                      28.274242
# 4                                       5.980941
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.043716                    4.536604
# 1                                      0.029528                    4.817406
# 2                                      0.075240                    5.007601
# 3                                      0.025064                    5.871338
# 4                                      0.067983                    4.739166
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.064252                  5792.756564
# 1                       0.093978                  1267.861250
# 2                       0.178138                   126.100723
# 3                       0.063874                  9578.078205
# 4                       0.031371                 91434.782971
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 2.775213                   0.005173
# 1                 2.353315                   0.007040
# 2                 2.067157                   0.011244
# 3                 6.402052                   0.001304
# 4                28.501489                   0.000872
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  19.975703                 0.014182                 0.183764
# 1                  25.004753                 0.040598                 0.210906
# 2                  24.083142                 0.051274                 0.292125
# 3                  91.217734                 0.049171                 0.116650
# 4                   9.737002                 0.018303                 0.016016
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.528082                 0.375975
# 1                   0.336182                 0.293785
# 2                   0.563923                 0.394181
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.551139                       22.743875
# 1                        7.651833                       26.045677
# 2                        8.781372                       22.277510
#
#    original_shape_Maximum2DDiameterColumn
# 0                               16.077739
# 1                               12.776208
# 2                               15.791279
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#
# Feature comuni utilizzate: 105
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=32, Classe 1=50, Totale=82
#   DOPO   - Test: Classe 0=32, Classe 1=32, Totale=64
#            Train: 0 → 18 (+18 campioni)
#
#  Split bilanciati creati con successo
#
#
# --------------------------------------------------------------------------------
# RISULTATI CROSS-DATASET
# --------------------------------------------------------------------------------
#  F1-score          : 0.5075
#  Accuracy          : 0.4844
#  Balanced Accuracy : 0.4844
#  ROC-AUC           : 0.3945
#
# CONFUSION MATRIX
# [[14 18]
#  [15 17]]
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.48      0.44      0.46        32
#            1       0.49      0.53      0.51        32
#
#     accuracy                           0.48        64
#    macro avg       0.48      0.48      0.48        64
# weighted avg       0.48      0.48      0.48        64
#
#
# ================================================================================
# CROSS-DATASET VALIDATION
# ================================================================================
# TRAIN: ambl_lesions_radiomic_medsam_binary
# TEST : duke_lesions_radiomic_medsam
# ================================================================================
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.632264
# 1   AMBL-001         0         0           0                   0.428066
# 2   AMBL-003         0         0           0                   0.853921
# 3   AMBL-005         1         1           0                   0.803782
# 4   AMBL-007         1         0           0                   0.631452
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.574573                       16.587860
# 1                 0.294263                       10.065943
# 2                 0.435016                        9.836007
# 3                 0.374899                       15.587523
# 4                 0.391559                       23.460339
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       28.869904                               22.120222
# 1                       34.207348                               17.412966
# 2                       22.610678                               21.247525
# 3                       41.577953                               34.491247
# 4                       59.915195                               44.173008
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            35.666937  ...
# 1                            36.743872  ...
# 2                            27.346457  ...
# 3                            42.427943  ...
# 4                            61.891243  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      11.866752
# 1                                       6.358452
# 2                                       8.132437
# 3                                      34.881141
# 4                                       5.821488
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.088645                    5.405028
# 1                                      0.055140                    5.483128
# 2                                      0.081316                    5.020232
# 3                                      0.025796                    5.568237
# 4                                      0.135345                    5.439009
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.043620                 17397.502279
# 1                       0.049725                  7036.435472
# 2                       0.054954                  4691.632692
# 3                       0.184971                   967.852818
# 4                       0.025776                106222.332082
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                13.115490                   0.001677
# 1                10.744731                   0.002468
# 2                 8.450972                   0.003567
# 3                 3.433053                   0.002188
# 4                57.721284                   0.000612
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  20.634441                 0.046452                 0.043755
# 1                  25.761844                 0.065802                 0.062361
# 2                  22.650386                 0.048524                 0.099512
# 3                 117.475529                 0.103989                 0.173719
# 4                  11.824437                 0.029061                 0.015007
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl_medsam): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.632264                 0.574573
# 1                   0.428066                 0.294263
# 2                   0.853921                 0.435016
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       16.587860                       28.869904
# 1                       10.065943                       34.207348
# 2                        9.836007                       22.610678
#
#    original_shape_Maximum2DDiameterColumn
# 0                               22.120222
# 1                               17.412966
# 2                               21.247525
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.956109
# 1   DUKE_002   0   0     0                   0.986617
# 2   DUKE_005   1   0     1                   0.531310
# 3   DUKE_009   0   0     0                   0.985995
# 4   DUKE_010   0   0     0                   0.913163
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.844657                       23.236690
# 1                 0.738184                       14.124854
# 2                 0.362991                       19.074218
# 3                 0.907380                       29.586478
# 4                 0.666651                       31.984526
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       27.510206                               33.841165
# 1                       19.134592                               21.804053
# 2                       52.547304                               55.177634
# 3                       32.606481                               40.022114
# 4                       47.977885                               60.524767
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            37.070079  ...
# 1                            25.679582  ...
# 2                            50.896657  ...
# 3                            42.657348  ...
# 4                            59.510315  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       4.065512
# 1                                     513.886736
# 2                                      20.795057
# 3                                     329.788184
# 4                                     938.945662
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.290643                    4.242751
# 1                                      0.013580                    7.206688
# 2                                      0.036582                    5.452188
# 3                                      0.004940                    7.262605
# 4                                      0.005418                    7.535492
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.017641                329513.249683
# 1                       0.507470                     9.310223
# 2                       0.039666                135505.922314
# 3                       0.301114                   212.257020
# 4                       0.569700                     4.200472
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0               116.318648                   0.000533
# 1                 0.471680                   0.002271
# 2                34.962085                   0.000325
# 3                 1.345384                   0.000424
# 4                 2.730941                   0.000165
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   7.410763                 0.012685                 0.010819
# 1                4216.436213                 0.432867                 3.156365
# 2                  30.408779                 0.017395                 0.016335
# 3                4459.712477                 0.074034                 1.055925
# 4               10483.944265                 0.453141                 0.369774
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke_medsam): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.956109                 0.844657
# 1                   0.986617                 0.738184
# 2                   0.531310                 0.362991
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       23.236690                       27.510206
# 1                       14.124854                       19.134592
# 2                       19.074218                       52.547304
#
#    original_shape_Maximum2DDiameterColumn
# 0                               33.841165
# 1                               21.804053
# 2                               55.177634
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#
# Feature comuni utilizzate: 105
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=123, Classe 1=168, Totale=291
#   DOPO   - Test: Classe 0=123, Classe 1=123, Totale=246
#            Train: 0 → 45 (+45 campioni)
#
#  Split bilanciati creati con successo
#
#
# --------------------------------------------------------------------------------
# RISULTATI CROSS-DATASET
# --------------------------------------------------------------------------------
#  F1-score          : 0.6341
#  Accuracy          : 0.5122
#  Balanced Accuracy : 0.5122
#  ROC-AUC           : 0.4496
#
# CONFUSION MATRIX
# [[ 22 101]
#  [ 19 104]]
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.54      0.18      0.27       123
#            1       0.51      0.85      0.63       123
#
#     accuracy                           0.51       246
#    macro avg       0.52      0.51      0.45       246
# weighted avg       0.52      0.51      0.45       246
#
#
# ================================================================================
# CROSS-DATASET VALIDATION
# ================================================================================
# TRAIN: duke_lesions_radiomic_medsam
# TEST : ambl_lesions_radiomic_medsam_binary
# ================================================================================
#   Shape: (291, 109)
#   Colonne: 109
#   Righe: 291
#   Patient ID  ER  PR  HER2  original_shape_Elongation  \
# 0   DUKE_001   0   0     1                   0.956109
# 1   DUKE_002   0   0     0                   0.986617
# 2   DUKE_005   1   0     1                   0.531310
# 3   DUKE_009   0   0     0                   0.985995
# 4   DUKE_010   0   0     0                   0.913163
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.844657                       23.236690
# 1                 0.738184                       14.124854
# 2                 0.362991                       19.074218
# 3                 0.907380                       29.586478
# 4                 0.666651                       31.984526
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       27.510206                               33.841165
# 1                       19.134592                               21.804053
# 2                       52.547304                               55.177634
# 3                       32.606481                               40.022114
# 4                       47.977885                               60.524767
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            37.070079  ...
# 1                            25.679582  ...
# 2                            50.896657  ...
# 3                            42.657348  ...
# 4                            59.510315  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       4.065512
# 1                                     513.886736
# 2                                      20.795057
# 3                                     329.788184
# 4                                     938.945662
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.290643                    4.242751
# 1                                      0.013580                    7.206688
# 2                                      0.036582                    5.452188
# 3                                      0.004940                    7.262605
# 4                                      0.005418                    7.535492
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.017641                329513.249683
# 1                       0.507470                     9.310223
# 2                       0.039666                135505.922314
# 3                       0.301114                   212.257020
# 4                       0.569700                     4.200472
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0               116.318648                   0.000533
# 1                 0.471680                   0.002271
# 2                34.962085                   0.000325
# 3                 1.345384                   0.000424
# 4                 2.730941                   0.000165
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                   7.410763                 0.012685                 0.010819
# 1                4216.436213                 0.432867                 3.156365
# 2                  30.408779                 0.017395                 0.016335
# 3                4459.712477                 0.074034                 1.055925
# 4               10483.944265                 0.453141                 0.369774
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER
# 1    168
# 0    123
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 123 (42.3%)
#   Classe 1: 168 (57.7%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER']
#   Altri target (duke_medsam): ['GRADE', 'isTN', 'PR', 'HER2']
#   Totale: 9
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#  Features estratte: 105 colonne, 291 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.956109                 0.844657
# 1                   0.986617                 0.738184
# 2                   0.531310                 0.362991
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       23.236690                       27.510206
# 1                       14.124854                       19.134592
# 2                       19.074218                       52.547304
#
#    original_shape_Maximum2DDiameterColumn
# 0                               33.841165
# 1                               21.804053
# 2                               55.177634
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (291, 105)
#   Shape: (82, 109)
#   Colonne: 109
#   Righe: 82
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.632264
# 1   AMBL-001         0         0           0                   0.428066
# 2   AMBL-003         0         0           0                   0.853921
# 3   AMBL-005         1         1           0                   0.803782
# 4   AMBL-007         1         0           0                   0.631452
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.574573                       16.587860
# 1                 0.294263                       10.065943
# 2                 0.435016                        9.836007
# 3                 0.374899                       15.587523
# 4                 0.391559                       23.460339
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       28.869904                               22.120222
# 1                       34.207348                               17.412966
# 2                       22.610678                               21.247525
# 3                       41.577953                               34.491247
# 4                       59.915195                               44.173008
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            35.666937  ...
# 1                            36.743872  ...
# 2                            27.346457  ...
# 3                            42.427943  ...
# 4                            61.891243  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      11.866752
# 1                                       6.358452
# 2                                       8.132437
# 3                                      34.881141
# 4                                       5.821488
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.088645                    5.405028
# 1                                      0.055140                    5.483128
# 2                                      0.081316                    5.020232
# 3                                      0.025796                    5.568237
# 4                                      0.135345                    5.439009
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.043620                 17397.502279
# 1                       0.049725                  7036.435472
# 2                       0.054954                  4691.632692
# 3                       0.184971                   967.852818
# 4                       0.025776                106222.332082
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                13.115490                   0.001677
# 1                10.744731                   0.002468
# 2                 8.450972                   0.003567
# 3                 3.433053                   0.002188
# 4                57.721284                   0.000612
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  20.634441                 0.046452                 0.043755
# 1                  25.761844                 0.065802                 0.062361
# 2                  22.650386                 0.048524                 0.099512
# 3                 117.475529                 0.103989                 0.173719
# 4                  11.824437                 0.029061                 0.015007
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    50
# 0    32
# Name: count, dtype: int64
#
#  Target selezionato:
#   Classe 0: 32 (39.0%)
#   Classe 1: 50 (61.0%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati + target): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target (ambl_medsam): ['PR [SII]', 'HER2 [SII]']
#   Totale: 7
#
#   Trovate: 4
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast']
#
#  Features estratte: 105 colonne, 82 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.632264                 0.574573
# 1                   0.428066                 0.294263
# 2                   0.853921                 0.435016
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       16.587860                       28.869904
# 1                       10.065943                       34.207348
# 2                        9.836007                       22.610678
#
#    original_shape_Maximum2DDiameterColumn
# 0                               22.120222
# 1                               17.412966
# 2                               21.247525
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (82, 105)
#
# Feature comuni utilizzate: 105
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=32, Classe 1=50, Totale=82
#   DOPO   - Test: Classe 0=32, Classe 1=32, Totale=64
#            Train: 0 → 18 (+18 campioni)
#
#  Split bilanciati creati con successo
#
#
# --------------------------------------------------------------------------------
# RISULTATI CROSS-DATASET
# --------------------------------------------------------------------------------
#  F1-score          : 0.5679
#  Accuracy          : 0.4531
#  Balanced Accuracy : 0.4531
#  ROC-AUC           : 0.5244
#
# CONFUSION MATRIX
# [[ 6 26]
#  [ 9 23]]
#
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#            0       0.40      0.19      0.26        32
#            1       0.47      0.72      0.57        32
#
#     accuracy                           0.45        64
#    macro avg       0.43      0.45      0.41        64
# weighted avg       0.43      0.45      0.41        64
#
#
#  Risultati cross-dataset aggiunti in:
# /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/cross_validation_rf.csv
#                    experiment                        train_dataset  \
# 0                AMBL_to_DUKE                  ambl_lesions_binary
# 1                DUKE_to_AMBL                         duke_lesions
# 2  AMBL_medsam_to_DUKE_medsam  ambl_lesions_radiomic_medsam_binary
# 3  DUKE_medsam_to_AMBL_medsam         duke_lesions_radiomic_medsam
#
#                           test_dataset  balance_test     f1  accuracy  \
# 0                         duke_lesions          True  0.326     0.496
# 1                  ambl_lesions_binary          True  0.507     0.484
# 2         duke_lesions_radiomic_medsam          True  0.634     0.512
# 3  ambl_lesions_radiomic_medsam_binary          True  0.568     0.453
#
#    balanced_accuracy    auc
# 0              0.496  0.470
# 1              0.484  0.395
# 2              0.512  0.450
# 3              0.453  0.524
