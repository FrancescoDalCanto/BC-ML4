# %% [markdown]
# # Import

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import re
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedGroupKFold, StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, balanced_accuracy_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

FILE_PATH = Path('/Users/francesco/Tesi/BC-ML4/dataset/cleaned')

TIPO_FOLD = "kfold"
BALANCE_TEST = True

# Mappa dei target per i dataset merged
TARGET_MAP = {
    "merged": "ER [SII]",
    "merged_medsam": "ER [SII]"
}

# %% [markdown]
# # VERIFICA LEAKAGE

# %%
def verify_no_leakage(file_path, csv_name, target_col):
    """
    Verifica sistematica per identificare possibili leakage
    """
    print("\n" + "="*80)
    print(f"VERIFICA LEAKAGE: {csv_name}")
    print("="*80)
    
    df = pd.read_csv(file_path)
    
    print(f"\n1. COLONNE TOTALI: {len(df.columns)}")
    print(f"\n2. DISTRIBUZIONE TARGET '{target_col}':")
    print(df[target_col].value_counts())
    
    # Calcola correlazione con il target
    print(f"\n3. TOP 20 FEATURES CORRELATE CON TARGET:")
    
    # Seleziona solo colonne numeriche
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    numeric_cols = [c for c in numeric_cols if c != target_col]
    
    correlations = {}
    for col in numeric_cols:
        if df[col].nunique() > 1:  # Skip costanti
            corr = abs(df[col].corr(df[target_col]))
            correlations[col] = corr
    
    sorted_corr = sorted(correlations.items(), key=lambda x: x[1], reverse=True)[:20]
    
    for col, corr in sorted_corr:
        print(f"  {col}: {corr:.4f}")
        if corr > 0.9:
            print(f"  CORRELAZIONE SOSPETTA!")
    
    # Verifica colonne con keyword sospette
    print(f"\n4. COLONNE CON KEYWORD SOSPETTE:")
    suspicious_keywords = ['target', 'label', 'class', 'diagnosis', 'positive', 
                          'negative', 'her2', 'er', 'pr', 'grade', 'receptor', 
                          'status', 'outcome', 'result']
    
    suspicious = []
    for col in df.columns:
        if any(kw in col.lower() for kw in suspicious_keywords):
            suspicious.append(col)
            print(f"  - {col}")
            print(f"    Tipo: {df[col].dtype}, Valori unici: {df[col].nunique()}")
            if df[col].dtype in ['int64', 'float64'] and df[col].nunique() == 2:
                print(f"     BINARIA - potrebbe essere un target!")
    
    # Verifica duplicati perfetti
    print(f"\n5. VERIFICA RIGHE DUPLICATE:")
    n_duplicates = df.duplicated().sum()
    print(f"  Righe duplicate: {n_duplicates}")
    if n_duplicates > 0:
        print(f"     ATTENZIONE: Ci sono duplicati!")
    
    # Verifica patient ID
    print(f"\n6. VERIFICA PATIENT ID:")
    print(f"  Pazienti unici: {df['Patient ID'].nunique()}")
    print(f"  Righe totali: {len(df)}")
    print(f"  Lesioni per paziente: {len(df) / df['Patient ID'].nunique():.2f}")
    
    # Verifica bilanciamento per dataset origine
    print(f"\n7. DISTRIBUZIONE PER DATASET ORIGINE:")
    df['origin'] = df['Patient ID'].apply(lambda x: 'DUKE' if 'DUKE' in str(x) else 'AMBL')
    print(df.groupby('origin')[target_col].value_counts().unstack(fill_value=0))
    
    return df

# %% [markdown]
# # Funzioni

# %%
def load_dataset(file_path, csv_name):
    """Carica il CSV"""
    df = pd.read_csv(file_path)

    # Informazioni base sul dataset_name
    print(f"  Shape: {df.shape}")
    print(f"  Colonne: {df.shape[1]}")
    print(f"  Righe: {df.shape[0]}")
    # Mostro solo le prime 5 righe
    print(df.head(5))

    if "Patient ID" not in df.columns:
        raise ValueError(f"{csv_name} - manca 'Patient ID'")
    return df.copy()

def select_target(df, target_col):
    """Verifica che il target sia valido"""
    
    # Evito di addestrare su colonne sbagliate
    if target_col not in df.columns:
        raise ValueError(f"Colonna '{target_col}' mancante")
    
    # Mostro valori PRIMA della selezione
    print(f"\n VALORI TARGET PRIMA DELLA PULIZIA:")
    print(f"  Tipo: {df[target_col].dtype}")
    print(f"  Valori unici: {sorted(df[target_col].dropna().unique())}")
    print(f"  NaN: {df[target_col].isna().sum()}")
    print(f"\n  Distribuzione:")
    print(df[target_col].value_counts(dropna=False))
    
    # Mostra distribuzione per dataset di origine
    print(f"\n  Distribuzione per dataset di origine:")
    df_temp = df.copy()
    df_temp['dataset_origin'] = df_temp['Patient ID'].apply(
        lambda x: 'DUKE' if str(x).startswith('DUKE') else 'AMBL'
    )
    print(df_temp.groupby('dataset_origin')[target_col].value_counts().unstack(fill_value=0))
    
    y = df[target_col]
    
    if y.nunique() < 2:
        raise ValueError(f"Target '{target_col}' ha una sola classe")
    
    # Statistiche più dettagliate
    print(f"\n Target selezionato:")
    print(f"  Classe 0: {(y==0).sum()} ({(y==0).sum()/len(y)*100:.1f}%)")
    print(f"  Classe 1: {(y==1).sum()} ({(y==1).sum()/len(y)*100:.1f}%)")
    
    return df, y


def build_features_and_groups(df, target_col, dataset_type):
    """Adattato per dataset merged - VERSIONE CORRETTA ANTI-LEAKAGE"""
    print(f"\n{'='*80}")
    print(f"COSTRUZIONE FEATURES E GROUPS")
    print(f"{'='*80}")
    
    # Serve per la StratifiedGroupKFold
    groups = df["Patient ID"].copy()
    
    # CORREZIONE: Lista completa di colonne da rimuovere per merged
    base_drop_cols = [
        "Patient ID",
        "lesion idx",           # AGGIUNTO
        "tumor/benign",         # AGGIUNTO
        "Breast",               # AGGIUNTO
        target_col
    ]

    # Altri target da rimuovere (TUTTI i target biomarcatori)
    other_targets = [
        "PR [SII]", 
        "ER [SII]",
        "HER2 [SII]",  # Rimuovo anche HER2 se non è il target
        "GRADE",       # AGGIUNTO - potrebbe essere presente da DUKE
        "isTN"         # AGGIUNTO - potrebbe essere presente da DUKE
    ]
    
    # Rimuovo il target corrente dalla lista degli altri target
    other_targets = [t for t in other_targets if t != target_col]
    
    drop_cols = base_drop_cols + other_targets
    
    # AGGIUNTO: Verifica esplicita delle colonne presenti
    print(f"\n COLONNE PRESENTI NEL DATAFRAME:")
    print(f"  Totale: {len(df.columns)}")
    print(f"\n  Prime 20 colonne:")
    for i, col in enumerate(df.columns[:20], 1):
        print(f"    {i}. {col}")
    
    # Mostro quali colonne vengono rimosse
    print(f"\n COLONNE DA RIMUOVERE:")  
    print(f"  Base (metadati): {base_drop_cols}")
    print(f"  Altri target: {other_targets}")
    print(f"  Totale da rimuovere: {len(drop_cols)}")
    
    # Verifico l'esistenza delle colonne
    cols_found = [c for c in drop_cols if c in df.columns]
    cols_missing = [c for c in drop_cols if c not in df.columns]
    
    print(f"\n  Trovate e rimosse: {len(cols_found)}")
    print(f"    {cols_found}")
    if cols_missing:
        print(f"  NON trovate (OK, verranno ignorate): {cols_missing}")
    
    # AGGIUNTO: Verifica colonne sospette rimaste
    suspicious_keywords = ['target', 'label', 'class', 'diagnosis', 'positive', 'negative', 
                           'her2', 'er', 'pr', 'grade', 'receptor', 'status']
    suspicious_cols = [c for c in df.columns if any(kw in c.lower() for kw in suspicious_keywords)]
    suspicious_cols = [c for c in suspicious_cols if c not in drop_cols]
    
    if suspicious_cols:
        print(f"\n  ATTENZIONE: Colonne potenzialmente sospette trovate:")
        for col in suspicious_cols:
            print(f"    - {col}")
            print(f"      Valori unici: {df[col].nunique()}")
            print(f"      Tipo: {df[col].dtype}")
    
    # Rimuovo le colonne
    X = df.drop(columns=drop_cols, errors="ignore")

    print(f"\n Features estratte: {X.shape[1]} colonne, {X.shape[0]} righe")
    
    # Verifico tipi e Nan
    print(f"\n{'='*80}")
    print("VERIFICA DATI")
    print(f"{'='*80}")
    
    # Mostra tipi di dato
    print(f"\n TIPI DI DATO:")
    print(X.dtypes.value_counts())
    
    # Conta NaN
    nan_count = X.isna().sum().sum()
    print(f"\n NaN PRESENTI: {nan_count}")
    
    if nan_count > 0:
        print(f"\n  Colonne con NaN (top 10):")
        nan_cols = X.isna().sum()
        print(nan_cols[nan_cols > 0].sort_values(ascending=False).head(10))
        
        # Conta righe con NaN
        rows_with_nan = X.isna().any(axis=1).sum()
        print(f"\n Righe con almeno un NaN: {rows_with_nan}/{len(X)}")
        
        print(f"\n  Queste righe verranno rimosse nella pipeline principale")
    else:
        print(f"\n Nessun NaN presente")
    
    # Mostra prime righe
    print(f"\n PRIME 3 RIGHE DEL DATASET FINALE:")
    print(X.head(3).iloc[:, :5]) 
    
    print(f"\n{'='*80}")
    print("VERIFICA PULIZIA NOMI COLONNE")
    print(f"{'='*80}")

    cols_with_special = [c for c in X.columns if any(char in c for char in ['[', ']', '<'])]

    print(f"\nColonne con caratteri speciali: {len(cols_with_special)}")

    if len(cols_with_special) > 0:
        print(f"  Esempi: {cols_with_special[:5]}")
        X.columns = [re.sub(r"\[|\]|<", "", c) for c in X.columns]
        print(f" Nomi colonne puliti")
    else:
        print(f" Nessuna colonna con caratteri speciali")
        print(f" Pulizia NON necessaria per questo dataset")


    print(f"\n FEATURES FINALI: {X.shape}")
    
    return X, groups

# %% [markdown]
# # StratifiedGroupKFold, StratifiedKFold

# %%
def stratifiedgroup(X, y, n_splits, groups):
    sgkf = StratifiedGroupKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )
    return list(sgkf.split(X, y, groups))

# %%
def stratified(X, y, n_splits):
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=42
    )
    return list(skf.split(X, y))

# %% [markdown]
# # Bilanciamento

# %%
def balance_test_sets(cv_splits, y):
    """
    Bilancia i test set a 50/50.
    I campioni in eccesso vengono spostati al training set.
    """
    balanced_splits = []
    
    print(f"\n{'='*80}")
    print("BILANCIAMENTO DEI TEST SET")
    print(f"{'='*80}\n")
    
    for fold_num, (train_idx, test_idx) in enumerate(cv_splits, 1):
        y_test = y.iloc[test_idx]
        
        # Indici per classe
        mask_0 = (y_test == 0).values
        mask_1 = (y_test == 1).values
        
        idx_0 = test_idx[mask_0]
        idx_1 = test_idx[mask_1]
        
        n_0 = len(idx_0)
        n_1 = len(idx_1)
        n_min = min(n_0, n_1)
        
        print(f"Fold {fold_num}:")
        print(f"  PRIMA  - Test: Classe 0={n_0}, Classe 1={n_1}, Totale={len(test_idx)}")
        
        # Campiona n_min per classe (bilanciamento 50/50)
        np.random.seed(42 + fold_num)
        idx_0_sampled = np.random.choice(idx_0, size=n_min, replace=False)
        idx_1_sampled = np.random.choice(idx_1, size=n_min, replace=False)
        
        # Test bilanciato
        test_idx_balanced = np.concatenate([idx_0_sampled, idx_1_sampled])
        
        # Campioni non usati → training
        unused = np.setdiff1d(test_idx, test_idx_balanced)
        train_idx_new = np.concatenate([train_idx, unused])
        
        print(f"  DOPO   - Test: Classe 0={n_min}, Classe 1={n_min}, Totale={n_min*2}")
        print(f"           Train: {len(train_idx)} → {len(train_idx_new)} (+{len(unused)} campioni)\n")
        
        # Verifica che sia perfettamente bilanciato
        assert len(idx_0_sampled) == len(idx_1_sampled), "Test set non bilanciato!"
        
        balanced_splits.append((train_idx_new, test_idx_balanced))
    
    print(f" Split bilanciati creati con successo\n")
    return balanced_splits

# %% [markdown]
# # Get model

# %%
def get_model(params=None):
    model= RandomForestClassifier(
        random_state=42,
        n_jobs=1,
        class_weight="balanced_subsample"
    )
    if params is not None:
        model.set_params(**params)
    return model

# %% [markdown]
# # Feature Importance

# %%
def get_feature_importance(model, feature_names):
    """
    Estrae feature importance da modelli tree-based (XGBoost)
    o modelli lineari (Logistic Regression).
    Ritorna DataFrame ordinato.
    """

    # Caso Pipeline sklearn
    if hasattr(model, "named_steps"):
        final_model = list(model.named_steps.values())[-1]
    else:
        final_model = model

    # XGBoost, RandomForest, ecc.
    if hasattr(final_model, "feature_importances_"):
        importances = final_model.feature_importances_

    # Logistic Regression
    elif hasattr(final_model, "coef_"):
        importances = np.abs(final_model.coef_[0])

    else:
        raise ValueError("Modello non supportato per feature importance")

    df = pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })

    df = df.sort_values("importance", ascending=False)

    return df

def save_feature_importance(df_importance, output_path, top_n=15):
    df_importance.head(top_n).to_csv(output_path, index=False)
    print(f" Salvate top-{top_n} feature in: {output_path}")

# %% [markdown]
# # Grid search

# %%
def gridsearch(X, y, splits):
    model = get_model()

    param_grid = {
        "n_estimators": [50, 75, 100],
        "max_depth": [2, 4, 6],
        "min_samples_leaf": [1, 2, 3]
    }


    grid = GridSearchCV(
        model,
        param_grid,
        cv=splits,
        scoring="f1",
        n_jobs=-1,
        verbose=1
    )

    grid.fit(X, y)
    return grid

# %% [markdown]
# # Valutazione fold

# %%
def evaluate_folds(X, y, splits, best_params):
    """
    Valuta il modello con i best params su ogni fold separatamente.
    Restituisce metriche per ogni fold.
    """
    fold_metrics = []
    
    for fold_num, (train_idx, test_idx) in enumerate(splits, 1):
        # Train
        model = get_model(best_params)
        model.fit(X.iloc[train_idx], y.iloc[train_idx])
        
        # Test
        y_test = y.iloc[test_idx]
        y_pred = model.predict(X.iloc[test_idx])
        y_prob = model.predict_proba(X.iloc[test_idx])[:, 1]
        
        # Metriche
        f1 = f1_score(y.iloc[test_idx], y_pred, zero_division=0)
        acc = accuracy_score(y.iloc[test_idx], y_pred)
        bal_acc = balanced_accuracy_score(y.iloc[test_idx], y_pred)
        auc = roc_auc_score(y.iloc[test_idx], y_prob)
        
        # Se il test set è bilanciato, ACC dovrebbe = BAL_ACC
        diff = abs(acc - bal_acc)

        # Stampo le metrice dei test set
        if True:
            print(f"\n{'='*80}")
            print(f"FOLD {fold_num}/{len(splits)}")
            print(f"{'='*80}")
            print(f"\n{'─'*80}")
            print("METRICHE TEST SET")
            print(f"{'─'*80}")
            print(f"  F1-score:          {f1:.4f}")
            print(f"  Accuracy:          {acc:.4f}")
            print(f"  Balanced Accuracy: {bal_acc:.4f}")
            print(f"  Differenza:        {diff:.6f}", end="")

            # Stampo la matrice di confusione
            print(f"\n{'─'*80}")
            print("CONFUSION MATRIX")
            print(f"{'─'*80}")
            
            cm = confusion_matrix(y_test, y_pred)
            print(cm)
            
            tn, fp, fn, tp = cm.ravel()
            print(f"\n  TN={tn} | FP={fp} | FN={fn} | TP={tp}")
            
            if (tn + fp) > 0:
                recall_0 = tn / (tn + fp)
                print(f"  Classe 0: {tn}/{tn+fp} corretti ({recall_0*100:.1f}%)")
            
            if (fn + tp) > 0:
                recall_1 = tp / (fn + tp)
                print(f"  Classe 1: {tp}/{fn+tp} corretti ({recall_1*100:.1f}%)")

            # Stampo il classification report
            print(f"\n{'─'*80}")
            print("CLASSIFICATION REPORT")
            print(f"{'─'*80}")
            print(classification_report(y_test, y_pred, zero_division=0))
        fold_metrics.append({
            "fold": fold_num,
            "f1": f1,
            "acc": acc,
            "bal_acc": bal_acc,
            "auc": auc,
            "acc_bal_diff": diff
        })
    
    # Stampa riepilogo performance per fold
    print(f"\n{'='*80}")
    print("RIEPILOGO PERFORMANCE PER FOLD")
    print(f"{'='*80}")
    print(f"{'Fold':<8} {'F1-Score':<12} {'Accuracy':<12} {'Bal. Acc':<12} {'AUC':<12}")
    print(f"{'─'*80}")
    for m in fold_metrics:
        print(f"{m['fold']:<8} {m['f1']:<12.4f} {m['acc']:<12.4f} {m['bal_acc']:<12.4f} {m['auc']:<12.4f}")
    print(f"{'─'*80}")
    print(f"{'Mean':<8} {np.mean([m['f1'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['acc'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['bal_acc'] for m in fold_metrics]):<12.4f} "
          f"{np.mean([m['auc'] for m in fold_metrics]):<12.4f}")
    print(f"{'Std':<8} {np.std([m['f1'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['acc'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['bal_acc'] for m in fold_metrics]):<12.4f} "
          f"{np.std([m['auc'] for m in fold_metrics]):<12.4f}")
    print(f"{'='*80}\n")
    
    return fold_metrics

# %% [markdown]
# # Trainig

# %%
def train(file_path, csv_name, dataset_type, tipo_fold, balance_test=False):
    """
    Pipeline completa di training per dataset merged.
    Esegue Grid Search con cross-validation e restituisce i migliori parametri.
    """
    print("\n" + "="*80)
    print(f"PROCESSING: {csv_name} ({dataset_type})")
    print("="*80)

    df = load_dataset(file_path, csv_name)

    target_col = TARGET_MAP[dataset_type]
    df, y = select_target(df, target_col)

    print(f"\nDistribuzione target:")
    for val in sorted(y.unique()):
        count = (y == val).sum()
        perc = count / len(y) * 100
        print(f"  Classe {val}: {count} ({perc:.1f}%)")

    # Preparo le feature e il group
    X, groups = build_features_and_groups(df, target_col, dataset_type)
    print(f"\n Features: {X.shape[1]} colonne")
    print(f" Campioni: {X.shape[0]}")
    print(f" Pazienti: {groups.nunique()}")


    # Creo gli split
    print(f"\n{'='*80}")
    print(f"CROSS-VALIDATION: {tipo_fold}")
    print(f"{'='*80}")

    if tipo_fold == "groupkfold":
        print(">>> StratifiedGroupKFold (pazienti separati)")
        splits_raw = stratifiedgroup(X, y, n_splits=5, groups=groups)
        
    elif tipo_fold == "kfold":
        print(">>> StratifiedKFold (standard)")
        splits_raw = stratified(X, y, n_splits=5)
        
    else:
        raise ValueError(
            f"tipo_fold '{tipo_fold}' non riconosciuto. "
            f"Usa: 'groupkfold' o 'kfold'"
        )
    
    # Bilancia test set se richiesto
    if balance_test:
        splits = balance_test_sets(splits_raw, y)
    else:
        splits = splits_raw
        print(f" Creati {len(splits)} fold (senza bilanciamento)")

    print(f" Creati {len(splits)} fold")

    # Eseguo la grid search
    grid = gridsearch(X, y, splits)

    fold_metrics = evaluate_folds(X, y, splits, grid.best_params_)

    # Calcola medie e std
    f1_scores = [m["f1"] for m in fold_metrics]
    acc_scores = [m["acc"] for m in fold_metrics]
    bal_acc_scores = [m["bal_acc"] for m in fold_metrics]
    auc_scores = [m["auc"] for m in fold_metrics]

    return {
        "dataset": csv_name,
        "target": target_col,
        "best_params": grid.best_params_,
        "mean_f1": np.mean(f1_scores),
        "std_f1": np.std(f1_scores),
        "mean_acc": np.mean(acc_scores),
        "std_acc": np.std(acc_scores),
        "mean_bal_acc": np.mean(bal_acc_scores),
        "std_bal_acc": np.std(bal_acc_scores),
        "mean_auc": np.mean(auc_scores),
        "std_auc": np.std(auc_scores),
        "fold_metrics": fold_metrics
    }

# %% [markdown]
# # Esecuzione

# %%
print("\n" + "="*80)
print("FASE 1: VERIFICA LEAKAGE")
print("="*80)

# ESEGUI VERIFICA SUI DATASET MERGED
print("\n\nVERIFICA MERGED STANDARD:")
df_check1 = verify_no_leakage(
    FILE_PATH / "merged_lesions.csv",
    "merged_lesions",
    "ER [SII]"
)

print("\n\nVERIFICA MERGED MEDSAM:")
df_check2 = verify_no_leakage(
    FILE_PATH / "merged_lesions_medsam.csv", 
    "merged_lesions_medsam",
    "ER [SII]"
)

# %% [markdown]
# # Esecuzione Training

# %%
print("\n" + "="*80)
print("FASE 2: TRAINING")
print("="*80)

results = {}

results["MERGED_ER"] = train(
    FILE_PATH / "merged_lesions.csv",
    "merged_lesions",
    dataset_type="merged",
    tipo_fold=TIPO_FOLD,
    balance_test=BALANCE_TEST
)

results["MERGED_medsam_ER"] = train(
    FILE_PATH / "merged_lesions_medsam.csv",
    "merged_lesions_medsam",
    dataset_type="merged_medsam",
    tipo_fold=TIPO_FOLD,
    balance_test=BALANCE_TEST
)

# Stampa risultati finali
print("\n" + "="*80)
print("RIEPILOGO FINALE")
print("="*80)

for name, res in results.items():
    print(f"\nDataset: {res['dataset']}")
    print("-" * 80)
    print(f" Target: {res['target']}")
    print(f"  F1-score         = {res['mean_f1']:.3f}  ±  {res['std_f1']:.3f}")
    print(f"  Accuracy         = {res['mean_acc']:.3f}  ±  {res['std_acc']:.3f}")
    print(f"  Balanced Acc     = {res['mean_bal_acc']:.3f}  ±  {res['std_bal_acc']:.3f}") 
    print(f"  AUC              = {res['mean_auc']:.3f}  ±  {res['std_auc']:.3f}")

# ============================
# Salvataggio risultati ER in CSV
# ============================

rows = []

for name, res in results.items():
    row = {
        "experiment": name,
        "dataset": res["dataset"],
        "target": res["target"],
        "mean_f1": round(res["mean_f1"], 3),
        "std_f1": round(res["std_f1"], 3),
        "mean_accuracy": round(res["mean_acc"], 3),
        "std_accuracy": round(res["std_acc"], 3),
        "mean_balanced_accuracy": round(res["mean_bal_acc"], 3),
        "std_balanced_accuracy": round(res["std_bal_acc"], 3),
        "mean_auc": round(res["mean_auc"], 3),
        "std_auc": round(res["std_auc"], 3)
    }
    rows.append(row)

df_PR = pd.DataFrame(rows)
df_PR = df_PR.round(3)
output_path = "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/rf_merged.csv"
df_PR.to_csv(output_path, index=False, float_format="%.3f")

print(f"\nRisultati ER salvati in:\n{output_path}")
# Out:
# ================================================================================
# FASE 1: VERIFICA LEAKAGE
# ================================================================================
#
#
# VERIFICA MERGED STANDARD:
#
# ================================================================================
# VERIFICA LEAKAGE: merged_lesions
# ================================================================================
#
# 1. COLONNE TOTALI: 109
#
# 2. DISTRIBUZIONE TARGET 'ER [SII]':
# ER [SII]
# 1    218
# 0    155
# Name: count, dtype: int64
#
# 3. TOP 20 FEATURES CORRELATE CON TARGET:
#   PR [SII]: 0.6843
#   original_shape_MeshVolume: 0.1338
#   original_shape_VoxelVolume: 0.1332
#   original_firstorder_TotalEnergy: 0.1255
#   original_shape_SurfaceVolumeRatio: 0.1251
#   original_gldm_DependenceNonUniformity: 0.1200
#   original_glrlm_RunLengthNonUniformity: 0.1103
#   original_glszm_LargeAreaHighGrayLevelEmphasis: 0.1097
#   original_glrlm_GrayLevelNonUniformity: 0.1072
#   original_glszm_LargeAreaEmphasis: 0.1065
#   original_glszm_SizeZoneNonUniformity: 0.1065
#   original_glszm_ZoneVariance: 0.1065
#   original_glszm_GrayLevelNonUniformity: 0.0970
#   original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0938
#   original_shape_LeastAxisLength: 0.0874
#   original_ngtdm_Coarseness: 0.0845
#   original_ngtdm_Busyness: 0.0744
#   original_glcm_Idmn: 0.0735
#   original_glcm_Imc1: 0.0715
#   original_shape_Maximum2DDiameterSlice: 0.0687
#
# 4. COLONNE CON KEYWORD SOSPETTE:
#   - ER [SII]
#     Tipo: int64, Valori unici: 2
#      BINARIA - potrebbe essere un target!
#   - PR [SII]
#     Tipo: int64, Valori unici: 2
#      BINARIA - potrebbe essere un target!
#   - HER2 [SII]
#     Tipo: int64, Valori unici: 2
#      BINARIA - potrebbe essere un target!
#   - original_shape_Maximum2DDiameterColumn
#     Tipo: float64, Valori unici: 371
#   - original_shape_Maximum2DDiameterRow
#     Tipo: float64, Valori unici: 373
#   - original_shape_Maximum2DDiameterSlice
#     Tipo: float64, Valori unici: 372
#   - original_shape_Maximum3DDiameter
#     Tipo: float64, Valori unici: 373
#   - original_shape_Sphericity
#     Tipo: float64, Valori unici: 373
#   - original_shape_SurfaceVolumeRatio
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_10Percentile
#     Tipo: float64, Valori unici: 278
#   - original_firstorder_90Percentile
#     Tipo: float64, Valori unici: 313
#   - original_firstorder_Entropy
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_InterquartileRange
#     Tipo: float64, Valori unici: 240
#   - original_firstorder_Kurtosis
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Maximum
#     Tipo: float64, Valori unici: 324
#   - original_firstorder_MeanAbsoluteDeviation
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Mean
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Median
#     Tipo: float64, Valori unici: 290
#   - original_firstorder_Minimum
#     Tipo: float64, Valori unici: 111
#   - original_firstorder_Range
#     Tipo: float64, Valori unici: 338
#   - original_firstorder_RobustMeanAbsoluteDeviation
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_RootMeanSquared
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Skewness
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_TotalEnergy
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Uniformity
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Variance
#     Tipo: float64, Valori unici: 373
#   - original_glcm_ClusterProminence
#     Tipo: float64, Valori unici: 373
#   - original_glcm_ClusterShade
#     Tipo: float64, Valori unici: 373
#   - original_glcm_ClusterTendency
#     Tipo: float64, Valori unici: 373
#   - original_glcm_DifferenceAverage
#     Tipo: float64, Valori unici: 373
#   - original_glcm_DifferenceEntropy
#     Tipo: float64, Valori unici: 373
#   - original_glcm_DifferenceVariance
#     Tipo: float64, Valori unici: 373
#   - original_glcm_InverseVariance
#     Tipo: float64, Valori unici: 373
#   - original_glcm_JointAverage
#     Tipo: float64, Valori unici: 373
#   - original_glcm_JointEnergy
#     Tipo: float64, Valori unici: 373
#   - original_glcm_MaximumProbability
#     Tipo: float64, Valori unici: 373
#   - original_glcm_SumAverage
#     Tipo: float64, Valori unici: 373
#   - original_glrlm_RunPercentage
#     Tipo: float64, Valori unici: 373
#   - original_glszm_ZonePercentage
#     Tipo: float64, Valori unici: 373
#
# 5. VERIFICA RIGHE DUPLICATE:
#   Righe duplicate: 0
#
# 6. VERIFICA PATIENT ID:
#   Pazienti unici: 361
#   Righe totali: 373
#   Lesioni per paziente: 1.03
#
# 7. DISTRIBUZIONE PER DATASET ORIGINE:
# ER [SII]    0    1
# origin
# AMBL       32   50
# DUKE      123  168
#
#
# VERIFICA MERGED MEDSAM:
#
# ================================================================================
# VERIFICA LEAKAGE: merged_lesions_medsam
# ================================================================================
#
# 1. COLONNE TOTALI: 109
#
# 2. DISTRIBUZIONE TARGET 'ER [SII]':
# ER [SII]
# 1    218
# 0    155
# Name: count, dtype: int64
#
# 3. TOP 20 FEATURES CORRELATE CON TARGET:
#   PR [SII]: 0.6843
#   original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.1344
#   original_shape_SurfaceVolumeRatio: 0.1312
#   original_shape_Flatness: 0.1141
#   original_shape_Elongation: 0.1112
#   original_firstorder_TotalEnergy: 0.1038
#   original_ngtdm_Coarseness: 0.0941
#   original_glszm_SizeZoneNonUniformity: 0.0817
#   original_glcm_Idn: 0.0787
#   original_gldm_DependenceNonUniformity: 0.0785
#   original_glcm_Idmn: 0.0780
#   original_shape_LeastAxisLength: 0.0747
#   original_shape_MinorAxisLength: 0.0722
#   original_shape_Maximum2DDiameterRow: 0.0705
#   original_glcm_ClusterTendency: 0.0698
#   original_glrlm_RunLengthNonUniformity: 0.0690
#   original_glcm_SumSquares: 0.0663
#   original_glcm_ClusterShade: 0.0649
#   original_glcm_ClusterProminence: 0.0644
#   original_gldm_LargeDependenceEmphasis: 0.0614
#
# 4. COLONNE CON KEYWORD SOSPETTE:
#   - ER [SII]
#     Tipo: int64, Valori unici: 2
#      BINARIA - potrebbe essere un target!
#   - PR [SII]
#     Tipo: int64, Valori unici: 2
#      BINARIA - potrebbe essere un target!
#   - HER2 [SII]
#     Tipo: int64, Valori unici: 2
#      BINARIA - potrebbe essere un target!
#   - original_shape_Maximum2DDiameterColumn
#     Tipo: float64, Valori unici: 371
#   - original_shape_Maximum2DDiameterRow
#     Tipo: float64, Valori unici: 373
#   - original_shape_Maximum2DDiameterSlice
#     Tipo: float64, Valori unici: 372
#   - original_shape_Maximum3DDiameter
#     Tipo: float64, Valori unici: 373
#   - original_shape_Sphericity
#     Tipo: float64, Valori unici: 373
#   - original_shape_SurfaceVolumeRatio
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_10Percentile
#     Tipo: float64, Valori unici: 239
#   - original_firstorder_90Percentile
#     Tipo: float64, Valori unici: 305
#   - original_firstorder_Entropy
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_InterquartileRange
#     Tipo: float64, Valori unici: 260
#   - original_firstorder_Kurtosis
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Maximum
#     Tipo: float64, Valori unici: 317
#   - original_firstorder_MeanAbsoluteDeviation
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Mean
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Median
#     Tipo: float64, Valori unici: 287
#   - original_firstorder_Minimum
#     Tipo: float64, Valori unici: 51
#   - original_firstorder_Range
#     Tipo: float64, Valori unici: 320
#   - original_firstorder_RobustMeanAbsoluteDeviation
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_RootMeanSquared
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Skewness
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_TotalEnergy
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Uniformity
#     Tipo: float64, Valori unici: 373
#   - original_firstorder_Variance
#     Tipo: float64, Valori unici: 373
#   - original_glcm_ClusterProminence
#     Tipo: float64, Valori unici: 373
#   - original_glcm_ClusterShade
#     Tipo: float64, Valori unici: 373
#   - original_glcm_ClusterTendency
#     Tipo: float64, Valori unici: 373
#   - original_glcm_DifferenceAverage
#     Tipo: float64, Valori unici: 373
#   - original_glcm_DifferenceEntropy
#     Tipo: float64, Valori unici: 373
#   - original_glcm_DifferenceVariance
#     Tipo: float64, Valori unici: 373
#   - original_glcm_InverseVariance
#     Tipo: float64, Valori unici: 373
#   - original_glcm_JointAverage
#     Tipo: float64, Valori unici: 373
#   - original_glcm_JointEnergy
#     Tipo: float64, Valori unici: 373
#   - original_glcm_MaximumProbability
#     Tipo: float64, Valori unici: 373
#   - original_glcm_SumAverage
#     Tipo: float64, Valori unici: 373
#   - original_glrlm_RunPercentage
#     Tipo: float64, Valori unici: 373
#   - original_glszm_ZonePercentage
#     Tipo: float64, Valori unici: 373
#
# 5. VERIFICA RIGHE DUPLICATE:
#   Righe duplicate: 0
#
# 6. VERIFICA PATIENT ID:
#   Pazienti unici: 361
#   Righe totali: 373
#   Lesioni per paziente: 1.03
#
# 7. DISTRIBUZIONE PER DATASET ORIGINE:
# ER [SII]    0    1
# origin
# AMBL       32   50
# DUKE      123  168
#
# ================================================================================
# FASE 2: TRAINING
# ================================================================================
#
# ================================================================================
# PROCESSING: merged_lesions (merged)
# ================================================================================
#   Shape: (373, 109)
#   Colonne: 109
#   Righe: 373
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.528082
# 1   AMBL-001         0         0           0                   0.336182
# 2   AMBL-003         0         0           0                   0.563923
# 3   AMBL-005         1         1           0                   0.761755
# 4   AMBL-007         1         0           0                   0.557584
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.375975                        8.551139
# 1                 0.293785                        7.651833
# 2                 0.394181                        8.781372
# 3                 0.641036                       20.245467
# 4                 0.366074                       18.597143
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.743875                               16.077739
# 1                       26.045677                               12.776208
# 2                       22.277510                               15.791279
# 3                       31.582394                               31.583382
# 4                       50.801628                               39.257160
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            26.863471  ...
# 1                            29.951350  ...
# 2                            22.006371  ...
# 3                            37.458189  ...
# 4                            60.793912  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      16.098904
# 1                                      10.777727
# 2                                       8.196991
# 3                                      28.274242
# 4                                       5.980941
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.043716                    4.536604
# 1                                      0.029528                    4.817406
# 2                                      0.075240                    5.007601
# 3                                      0.025064                    5.871338
# 4                                      0.067983                    4.739166
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.064252                  5792.756564
# 1                       0.093978                  1267.861250
# 2                       0.178138                   126.100723
# 3                       0.063874                  9578.078205
# 4                       0.031371                 91434.782971
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 2.775213                   0.005173
# 1                 2.353315                   0.007040
# 2                 2.067157                   0.011244
# 3                 6.402052                   0.001304
# 4                28.501489                   0.000872
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  19.975703                 0.014182                 0.183764
# 1                  25.004753                 0.040598                 0.210906
# 2                  24.083142                 0.051274                 0.292125
# 3                  91.217734                 0.049171                 0.116650
# 4                   9.737002                 0.018303                 0.016016
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    218
# 0    155
# Name: count, dtype: int64
#
#   Distribuzione per dataset di origine:
# ER [SII]          0    1
# dataset_origin
# AMBL             32   50
# DUKE            123  168
#
#  Target selezionato:
#   Classe 0: 155 (41.6%)
#   Classe 1: 218 (58.4%)
#
# Distribuzione target:
#   Classe 0: 155 (41.6%)
#   Classe 1: 218 (58.4%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE PRESENTI NEL DATAFRAME:
#   Totale: 109
#
#   Prime 20 colonne:
#     1. Patient ID
#     2. ER [SII]
#     3. PR [SII]
#     4. HER2 [SII]
#     5. original_shape_Elongation
#     6. original_shape_Flatness
#     7. original_shape_LeastAxisLength
#     8. original_shape_MajorAxisLength
#     9. original_shape_Maximum2DDiameterColumn
#     10. original_shape_Maximum2DDiameterRow
#     11. original_shape_Maximum2DDiameterSlice
#     12. original_shape_Maximum3DDiameter
#     13. original_shape_MeshVolume
#     14. original_shape_MinorAxisLength
#     15. original_shape_Sphericity
#     16. original_shape_SurfaceArea
#     17. original_shape_SurfaceVolumeRatio
#     18. original_shape_VoxelVolume
#     19. original_firstorder_10Percentile
#     20. original_firstorder_90Percentile
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target: ['PR [SII]', 'HER2 [SII]', 'GRADE', 'isTN']
#   Totale da rimuovere: 9
#
#   Trovate e rimosse: 4
#     ['Patient ID', 'ER [SII]', 'PR [SII]', 'HER2 [SII]']
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#   ATTENZIONE: Colonne potenzialmente sospette trovate:
#     - original_shape_Maximum2DDiameterColumn
#       Valori unici: 371
#       Tipo: float64
#     - original_shape_Maximum2DDiameterRow
#       Valori unici: 373
#       Tipo: float64
#     - original_shape_Maximum2DDiameterSlice
#       Valori unici: 372
#       Tipo: float64
#     - original_shape_Maximum3DDiameter
#       Valori unici: 373
#       Tipo: float64
#     - original_shape_Sphericity
#       Valori unici: 373
#       Tipo: float64
#     - original_shape_SurfaceVolumeRatio
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_10Percentile
#       Valori unici: 278
#       Tipo: float64
#     - original_firstorder_90Percentile
#       Valori unici: 313
#       Tipo: float64
#     - original_firstorder_Entropy
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_InterquartileRange
#       Valori unici: 240
#       Tipo: float64
#     - original_firstorder_Kurtosis
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Maximum
#       Valori unici: 324
#       Tipo: float64
#     - original_firstorder_MeanAbsoluteDeviation
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Mean
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Median
#       Valori unici: 290
#       Tipo: float64
#     - original_firstorder_Minimum
#       Valori unici: 111
#       Tipo: float64
#     - original_firstorder_Range
#       Valori unici: 338
#       Tipo: float64
#     - original_firstorder_RobustMeanAbsoluteDeviation
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_RootMeanSquared
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Skewness
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_TotalEnergy
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Uniformity
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Variance
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_ClusterProminence
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_ClusterShade
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_ClusterTendency
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_DifferenceAverage
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_DifferenceEntropy
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_DifferenceVariance
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_InverseVariance
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_JointAverage
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_JointEnergy
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_MaximumProbability
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_SumAverage
#       Valori unici: 373
#       Tipo: float64
#     - original_glrlm_RunPercentage
#       Valori unici: 373
#       Tipo: float64
#     - original_glszm_ZonePercentage
#       Valori unici: 373
#       Tipo: float64
#
#  Features estratte: 105 colonne, 373 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.528082                 0.375975
# 1                   0.336182                 0.293785
# 2                   0.563923                 0.394181
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.551139                       22.743875
# 1                        7.651833                       26.045677
# 2                        8.781372                       22.277510
#
#    original_shape_Maximum2DDiameterColumn
# 0                               16.077739
# 1                               12.776208
# 2                               15.791279
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (373, 105)
#
#  Features: 105 colonne
#  Campioni: 373
#  Pazienti: 361
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=31, Classe 1=44, Totale=75
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 298 → 311 (+13 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=31, Classe 1=44, Totale=75
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 298 → 311 (+13 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=31, Classe 1=44, Totale=75
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 298 → 311 (+13 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=31, Classe 1=43, Totale=74
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 299 → 311 (+12 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=31, Classe 1=43, Totale=74
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 299 → 311 (+12 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6053
#   Accuracy:          0.5161
#   Balanced Accuracy: 0.5161
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[ 9 22]
#  [ 8 23]]
#
#   TN=9 | FP=22 | FN=8 | TP=23
#   Classe 0: 9/31 corretti (29.0%)
#   Classe 1: 23/31 corretti (74.2%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.53      0.29      0.38        31
#            1       0.51      0.74      0.61        31
#
#     accuracy                           0.52        62
#    macro avg       0.52      0.52      0.49        62
# weighted avg       0.52      0.52      0.49        62
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6216
#   Accuracy:          0.5484
#   Balanced Accuracy: 0.5484
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11 20]
#  [ 8 23]]
#
#   TN=11 | FP=20 | FN=8 | TP=23
#   Classe 0: 11/31 corretti (35.5%)
#   Classe 1: 23/31 corretti (74.2%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.58      0.35      0.44        31
#            1       0.53      0.74      0.62        31
#
#     accuracy                           0.55        62
#    macro avg       0.56      0.55      0.53        62
# weighted avg       0.56      0.55      0.53        62
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6269
#   Accuracy:          0.5968
#   Balanced Accuracy: 0.5968
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[16 15]
#  [10 21]]
#
#   TN=16 | FP=15 | FN=10 | TP=21
#   Classe 0: 16/31 corretti (51.6%)
#   Classe 1: 21/31 corretti (67.7%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.62      0.52      0.56        31
#            1       0.58      0.68      0.63        31
#
#     accuracy                           0.60        62
#    macro avg       0.60      0.60      0.59        62
# weighted avg       0.60      0.60      0.59        62
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6667
#   Accuracy:          0.6290
#   Balanced Accuracy: 0.6290
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[16 15]
#  [ 8 23]]
#
#   TN=16 | FP=15 | FN=8 | TP=23
#   Classe 0: 16/31 corretti (51.6%)
#   Classe 1: 23/31 corretti (74.2%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.67      0.52      0.58        31
#            1       0.61      0.74      0.67        31
#
#     accuracy                           0.63        62
#    macro avg       0.64      0.63      0.62        62
# weighted avg       0.64      0.63      0.62        62
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6494
#   Accuracy:          0.5645
#   Balanced Accuracy: 0.5645
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[10 21]
#  [ 6 25]]
#
#   TN=10 | FP=21 | FN=6 | TP=25
#   Classe 0: 10/31 corretti (32.3%)
#   Classe 1: 25/31 corretti (80.6%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.62      0.32      0.43        31
#            1       0.54      0.81      0.65        31
#
#     accuracy                           0.56        62
#    macro avg       0.58      0.56      0.54        62
# weighted avg       0.58      0.56      0.54        62
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.6053       0.5161       0.5161       0.5713
# 2        0.6216       0.5484       0.5484       0.4932
# 3        0.6269       0.5968       0.5968       0.5369
# 4        0.6667       0.6290       0.6290       0.5890
# 5        0.6494       0.5645       0.5645       0.5640
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.6340       0.5710       0.5710       0.5509
# Std      0.0216       0.0390       0.0390       0.0333
# ================================================================================
#
#
# ================================================================================
# PROCESSING: merged_lesions_medsam (merged_medsam)
# ================================================================================
#   Shape: (373, 109)
#   Colonne: 109
#   Righe: 373
#   Patient ID  ER [SII]  PR [SII]  HER2 [SII]  original_shape_Elongation  \
# 0   AMBL-001         0         0           0                   0.632264
# 1   AMBL-001         0         0           0                   0.428066
# 2   AMBL-003         0         0           0                   0.853921
# 3   AMBL-005         1         1           0                   0.803782
# 4   AMBL-007         1         0           0                   0.631452
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.574573                       16.587860
# 1                 0.294263                       10.065943
# 2                 0.435016                        9.836007
# 3                 0.374899                       15.587523
# 4                 0.391559                       23.460339
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       28.869904                               22.120222
# 1                       34.207348                               17.412966
# 2                       22.610678                               21.247525
# 3                       41.577953                               34.491247
# 4                       59.915195                               44.173008
#
#    original_shape_Maximum2DDiameterRow  ...  \
# 0                            35.666937  ...
# 1                            36.743872  ...
# 2                            27.346457  ...
# 3                            42.427943  ...
# 4                            61.891243  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      11.866752
# 1                                       6.358452
# 2                                       8.132437
# 3                                      34.881141
# 4                                       5.821488
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      0.088645                    5.405028
# 1                                      0.055140                    5.483128
# 2                                      0.081316                    5.020232
# 3                                      0.025796                    5.568237
# 4                                      0.135345                    5.439009
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.043620                 17397.502279
# 1                       0.049725                  7036.435472
# 2                       0.054954                  4691.632692
# 3                       0.184971                   967.852818
# 4                       0.025776                106222.332082
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                13.115490                   0.001677
# 1                10.744731                   0.002468
# 2                 8.450972                   0.003567
# 3                 3.433053                   0.002188
# 4                57.721284                   0.000612
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 0                  20.634441                 0.046452                 0.043755
# 1                  25.761844                 0.065802                 0.062361
# 2                  22.650386                 0.048524                 0.099512
# 3                 117.475529                 0.103989                 0.173719
# 4                  11.824437                 0.029061                 0.015007
#
# [5 rows x 109 columns]
#
#  VALORI TARGET PRIMA DELLA PULIZIA:
#   Tipo: int64
#   Valori unici: [np.int64(0), np.int64(1)]
#   NaN: 0
#
#   Distribuzione:
# ER [SII]
# 1    218
# 0    155
# Name: count, dtype: int64
#
#   Distribuzione per dataset di origine:
# ER [SII]          0    1
# dataset_origin
# AMBL             32   50
# DUKE            123  168
#
#  Target selezionato:
#   Classe 0: 155 (41.6%)
#   Classe 1: 218 (58.4%)
#
# Distribuzione target:
#   Classe 0: 155 (41.6%)
#   Classe 1: 218 (58.4%)
#
# ================================================================================
# COSTRUZIONE FEATURES E GROUPS
# ================================================================================
#
#  COLONNE PRESENTI NEL DATAFRAME:
#   Totale: 109
#
#   Prime 20 colonne:
#     1. Patient ID
#     2. ER [SII]
#     3. PR [SII]
#     4. HER2 [SII]
#     5. original_shape_Elongation
#     6. original_shape_Flatness
#     7. original_shape_LeastAxisLength
#     8. original_shape_MajorAxisLength
#     9. original_shape_Maximum2DDiameterColumn
#     10. original_shape_Maximum2DDiameterRow
#     11. original_shape_Maximum2DDiameterSlice
#     12. original_shape_Maximum3DDiameter
#     13. original_shape_MeshVolume
#     14. original_shape_MinorAxisLength
#     15. original_shape_Sphericity
#     16. original_shape_SurfaceArea
#     17. original_shape_SurfaceVolumeRatio
#     18. original_shape_VoxelVolume
#     19. original_firstorder_10Percentile
#     20. original_firstorder_90Percentile
#
#  COLONNE DA RIMUOVERE:
#   Base (metadati): ['Patient ID', 'lesion idx', 'tumor/benign', 'Breast', 'ER [SII]']
#   Altri target: ['PR [SII]', 'HER2 [SII]', 'GRADE', 'isTN']
#   Totale da rimuovere: 9
#
#   Trovate e rimosse: 4
#     ['Patient ID', 'ER [SII]', 'PR [SII]', 'HER2 [SII]']
#   NON trovate (OK, verranno ignorate): ['lesion idx', 'tumor/benign', 'Breast', 'GRADE', 'isTN']
#
#   ATTENZIONE: Colonne potenzialmente sospette trovate:
#     - original_shape_Maximum2DDiameterColumn
#       Valori unici: 371
#       Tipo: float64
#     - original_shape_Maximum2DDiameterRow
#       Valori unici: 373
#       Tipo: float64
#     - original_shape_Maximum2DDiameterSlice
#       Valori unici: 372
#       Tipo: float64
#     - original_shape_Maximum3DDiameter
#       Valori unici: 373
#       Tipo: float64
#     - original_shape_Sphericity
#       Valori unici: 373
#       Tipo: float64
#     - original_shape_SurfaceVolumeRatio
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_10Percentile
#       Valori unici: 239
#       Tipo: float64
#     - original_firstorder_90Percentile
#       Valori unici: 305
#       Tipo: float64
#     - original_firstorder_Entropy
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_InterquartileRange
#       Valori unici: 260
#       Tipo: float64
#     - original_firstorder_Kurtosis
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Maximum
#       Valori unici: 317
#       Tipo: float64
#     - original_firstorder_MeanAbsoluteDeviation
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Mean
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Median
#       Valori unici: 287
#       Tipo: float64
#     - original_firstorder_Minimum
#       Valori unici: 51
#       Tipo: float64
#     - original_firstorder_Range
#       Valori unici: 320
#       Tipo: float64
#     - original_firstorder_RobustMeanAbsoluteDeviation
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_RootMeanSquared
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Skewness
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_TotalEnergy
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Uniformity
#       Valori unici: 373
#       Tipo: float64
#     - original_firstorder_Variance
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_ClusterProminence
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_ClusterShade
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_ClusterTendency
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_DifferenceAverage
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_DifferenceEntropy
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_DifferenceVariance
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_InverseVariance
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_JointAverage
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_JointEnergy
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_MaximumProbability
#       Valori unici: 373
#       Tipo: float64
#     - original_glcm_SumAverage
#       Valori unici: 373
#       Tipo: float64
#     - original_glrlm_RunPercentage
#       Valori unici: 373
#       Tipo: float64
#     - original_glszm_ZonePercentage
#       Valori unici: 373
#       Tipo: float64
#
#  Features estratte: 105 colonne, 373 righe
#
# ================================================================================
# VERIFICA DATI
# ================================================================================
#
#  TIPI DI DATO:
# float64    105
# Name: count, dtype: int64
#
#  NaN PRESENTI: 0
#
#  Nessun NaN presente
#
#  PRIME 3 RIGHE DEL DATASET FINALE:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.632264                 0.574573
# 1                   0.428066                 0.294263
# 2                   0.853921                 0.435016
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       16.587860                       28.869904
# 1                       10.065943                       34.207348
# 2                        9.836007                       22.610678
#
#    original_shape_Maximum2DDiameterColumn
# 0                               22.120222
# 1                               17.412966
# 2                               21.247525
#
# ================================================================================
# VERIFICA PULIZIA NOMI COLONNE
# ================================================================================
#
# Colonne con caratteri speciali: 0
#  Nessuna colonna con caratteri speciali
#  Pulizia NON necessaria per questo dataset
#
#  FEATURES FINALI: (373, 105)
#
#  Features: 105 colonne
#  Campioni: 373
#  Pazienti: 361
#
# ================================================================================
# CROSS-VALIDATION: kfold
# ================================================================================
# >>> StratifiedKFold (standard)
#
# ================================================================================
# BILANCIAMENTO DEI TEST SET
# ================================================================================
#
# Fold 1:
#   PRIMA  - Test: Classe 0=31, Classe 1=44, Totale=75
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 298 → 311 (+13 campioni)
#
# Fold 2:
#   PRIMA  - Test: Classe 0=31, Classe 1=44, Totale=75
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 298 → 311 (+13 campioni)
#
# Fold 3:
#   PRIMA  - Test: Classe 0=31, Classe 1=44, Totale=75
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 298 → 311 (+13 campioni)
#
# Fold 4:
#   PRIMA  - Test: Classe 0=31, Classe 1=43, Totale=74
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 299 → 311 (+12 campioni)
#
# Fold 5:
#   PRIMA  - Test: Classe 0=31, Classe 1=43, Totale=74
#   DOPO   - Test: Classe 0=31, Classe 1=31, Totale=62
#            Train: 299 → 311 (+12 campioni)
#
#  Split bilanciati creati con successo
#
#  Creati 5 fold
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
#
# ================================================================================
# FOLD 1/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6667
#   Accuracy:          0.5806
#   Balanced Accuracy: 0.5806
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[10 21]
#  [ 5 26]]
#
#   TN=10 | FP=21 | FN=5 | TP=26
#   Classe 0: 10/31 corretti (32.3%)
#   Classe 1: 26/31 corretti (83.9%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.67      0.32      0.43        31
#            1       0.55      0.84      0.67        31
#
#     accuracy                           0.58        62
#    macro avg       0.61      0.58      0.55        62
# weighted avg       0.61      0.58      0.55        62
#
#
# ================================================================================
# FOLD 2/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6575
#   Accuracy:          0.5968
#   Balanced Accuracy: 0.5968
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[13 18]
#  [ 7 24]]
#
#   TN=13 | FP=18 | FN=7 | TP=24
#   Classe 0: 13/31 corretti (41.9%)
#   Classe 1: 24/31 corretti (77.4%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.65      0.42      0.51        31
#            1       0.57      0.77      0.66        31
#
#     accuracy                           0.60        62
#    macro avg       0.61      0.60      0.58        62
# weighted avg       0.61      0.60      0.58        62
#
#
# ================================================================================
# FOLD 3/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6027
#   Accuracy:          0.5323
#   Balanced Accuracy: 0.5323
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11 20]
#  [ 9 22]]
#
#   TN=11 | FP=20 | FN=9 | TP=22
#   Classe 0: 11/31 corretti (35.5%)
#   Classe 1: 22/31 corretti (71.0%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.55      0.35      0.43        31
#            1       0.52      0.71      0.60        31
#
#     accuracy                           0.53        62
#    macro avg       0.54      0.53      0.52        62
# weighted avg       0.54      0.53      0.52        62
#
#
# ================================================================================
# FOLD 4/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.7059
#   Accuracy:          0.6774
#   Balanced Accuracy: 0.6774
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[18 13]
#  [ 7 24]]
#
#   TN=18 | FP=13 | FN=7 | TP=24
#   Classe 0: 18/31 corretti (58.1%)
#   Classe 1: 24/31 corretti (77.4%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.72      0.58      0.64        31
#            1       0.65      0.77      0.71        31
#
#     accuracy                           0.68        62
#    macro avg       0.68      0.68      0.67        62
# weighted avg       0.68      0.68      0.67        62
#
#
# ================================================================================
# FOLD 5/5
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# METRICHE TEST SET
# ────────────────────────────────────────────────────────────────────────────────
#   F1-score:          0.6579
#   Accuracy:          0.5806
#   Balanced Accuracy: 0.5806
#   Differenza:        0.000000
# ────────────────────────────────────────────────────────────────────────────────
# CONFUSION MATRIX
# ────────────────────────────────────────────────────────────────────────────────
# [[11 20]
#  [ 6 25]]
#
#   TN=11 | FP=20 | FN=6 | TP=25
#   Classe 0: 11/31 corretti (35.5%)
#   Classe 1: 25/31 corretti (80.6%)
#
# ────────────────────────────────────────────────────────────────────────────────
# CLASSIFICATION REPORT
# ────────────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#            0       0.65      0.35      0.46        31
#            1       0.56      0.81      0.66        31
#
#     accuracy                           0.58        62
#    macro avg       0.60      0.58      0.56        62
# weighted avg       0.60      0.58      0.56        62
#
#
# ================================================================================
# RIEPILOGO PERFORMANCE PER FOLD
# ================================================================================
# Fold     F1-Score     Accuracy     Bal. Acc     AUC
# ────────────────────────────────────────────────────────────────────────────────
# 1        0.6667       0.5806       0.5806       0.6285
# 2        0.6575       0.5968       0.5968       0.5890
# 3        0.6027       0.5323       0.5323       0.5952
# 4        0.7059       0.6774       0.6774       0.6889
# 5        0.6579       0.5806       0.5806       0.5963
# ────────────────────────────────────────────────────────────────────────────────
# Mean     0.6581       0.5935       0.5935       0.6196
# Std      0.0329       0.0472       0.0472       0.0373
# ================================================================================
#
#
# ================================================================================
# RIEPILOGO FINALE
# ================================================================================
#
# Dataset: merged_lesions
# --------------------------------------------------------------------------------
#  Target: ER [SII]
#   F1-score         = 0.634  ±  0.022
#   Accuracy         = 0.571  ±  0.039
#   Balanced Acc     = 0.571  ±  0.039
#   AUC              = 0.551  ±  0.033
#
# Dataset: merged_lesions_medsam
# --------------------------------------------------------------------------------
#  Target: ER [SII]
#   F1-score         = 0.658  ±  0.033
#   Accuracy         = 0.594  ±  0.047
#   Balanced Acc     = 0.594  ±  0.047
#   AUC              = 0.620  ±  0.037
#
# Risultati ER salvati in:
# /Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/rf_merged.csv

# %% [markdown]
# # Esecuzione Feature Importance

# %%
print("\n" + "="*80)
print("CALCOLO FEATURE IMPORTANCE (XGBoost - ER MERGED)")
print("="*80)

# MERGED
print("\n>>> FEATURE IMPORTANCE MERGED")

best_params_fi = results["MERGED_ER"]["best_params"]

df_fi = load_dataset(
    FILE_PATH / "merged_lesions.csv",
    "merged_lesions"
)

df_fi, y_fi = select_target(df_fi, TARGET_MAP["merged"])
X_fi, _ = build_features_and_groups(df_fi, TARGET_MAP["merged"], "merged")

model_fi = get_model(best_params_fi)
model_fi.fit(X_fi, y_fi)

fi_df = get_feature_importance(model_fi, X_fi.columns)

# save_feature_importance(
#     fi_df,
#     "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_MERGED_ER.csv",
#     top_n=20
# )

# MERGED MEDSAM
print("\n>>> FEATURE IMPORTANCE MERGED MEDSAM")

best_params_fi = results["MERGED_medsam_ER"]["best_params"]

df_fi = load_dataset(
    FILE_PATH / "merged_lesions_medsam.csv",
    "merged_lesions_medsam"
)

df_fi, y_fi = select_target(df_fi, TARGET_MAP["merged_medsam"])
X_fi, _ = build_features_and_groups(df_fi, TARGET_MAP["merged_medsam"], "merged_medsam")

model_fi = get_model(best_params_fi)
model_fi.fit(X_fi, y_fi)

fi_df = get_feature_importance(model_fi, X_fi.columns)

# save_feature_importance(
#     fi_df,
#     "/Users/francesco/Tesi/BC-ML4/src/modelli_singoli/RandomForest/feature_importance_MERGED_medsam_ER.csv",
#     top_n=20
# )

print("\n" + "="*80)
print("COMPLETATO!")
print("="*80)
